# %%
import os
import re
import json
import fitz  # PyMuPDF
import numpy as np
import requests
from transformers import MarianTokenizer, MarianMTModel
from tqdm import tqdm

# %%
# ---------- CONFIG ----------
DATA_DIR = "../../rag/data/labor_law"
MAX_TOKENS = 512  # MarianMT maximum token limit (safe upper bound)
AR_PDF = os.path.join(DATA_DIR, "labor_law_ar.pdf")
AR_URL = "https://www.hrsd.gov.sa/sites/default/files/2025-07/nzam-al-ml----wfq-alhwyt-aljdydt-2.pdf"
JSON_PATH = os.path.join(DATA_DIR, "labor_law_parsed.json")
os.makedirs(DATA_DIR, exist_ok=True)

# %%
# -----------------------------
# Arabic Number Conversion (up to 999)
# -----------------------------

UNITS = {
    "صفر": 0, "واحد": 1, "واحدة": 1, "أول": 1, "الأول": 1, "الأولى": 1, "الحادية" : 1,
    "اثنان": 2, "اثنين": 2, "إثنان": 2, "الثاني": 2, "الثانية": 2,
    "ثلاثة": 3, "الثالث": 3, "الثالثة": 3,
    "أربعة": 4, "الرابع": 4, "الرابعة": 4,
    "خمسة": 5, "الخامس": 5, "الخامسة": 5,
    "ستة": 6, "السادس": 6, "السادسة": 6,
    "سبعة": 7, "السابع": 7, "السابعة": 7,
    "ثمانية": 8, "الثامن": 8, "الثامنة": 8,
    "تسعة": 9, "التاسع": 9, "التاسعة": 9,
    "عشرة": 10, "العاشر": 10, "العاشرة": 10,
    "إحدى عشرة": 11, "الحادي عشر": 11, "الحادية عشرة": 11,
    "اثنا عشر": 12, "الثاني عشر": 12, "الثانية عشرة": 12,
    "ثلاثة عشر": 13, "الثالث عشر": 13,
    "أربعة عشر": 14, "الرابع عشر": 14,
    "خمسة عشر": 15, "الخامس عشر": 15,
    "ستة عشر": 16, "السادس عشر": 16,
    "سبعة عشر": 17, "السابع عشر": 17,
    "ثمانية عشر": 18, "الثامن عشر": 18,
    "تسعة عشر": 19, "التاسع عشر": 19
}

TENS = {
    "عشرون": 20, "العشرون": 20,"عشرين": 20, "العشرين": 20,
    "ثلاثون": 30, "الثلاثون" : 30, "ثلاثين": 30, "الثلاثين" : 30,
    "أربعون": 40, "الأربعون": 40,"أربعين": 40, "الأربعين": 40,
    "خمسون": 50,"الخمسون" : 50,"خمسين": 50,"الخمسين" : 50,
    "ستون": 60, "الستون": 60,"ستين": 60, "الستين": 60,
    "سبعون": 70, "السبعون": 70,"سبعين": 70, "السبعين": 70,
    "ثمانون": 80, "الثمانون": 80,"ثمانين": 80, "الثمانين": 80,
    "تسعون": 90 , "التسعون" : 90,"تسعين": 90 , "التسعين" : 90
}

HUNDREDS = {
    "مائة": 100, "المائة": 100,
    "مائتان": 200, "المائتين": 200,"المئتان":200,
    "ثلاثمائة": 300, "أربعمائة": 400,
    "خمسمائة": 500, "ستمائة": 600,
    "سبعمائة": 700, "ثمانمائة": 800,
    "تسعمائة": 900
}

# %%
def arabic_text_to_number(text: str) -> int:
    text = text.replace(" و", " ").strip()
    total = 0
    if "بعد" in text:
        left, right = text.split("بعد", 1)
        return arabic_text_to_number(right.strip()) + arabic_text_to_number(left.strip())
    for word in text.split():
        if word in HUNDREDS:
            total += HUNDREDS[word]
        elif word in TENS:
            total += TENS[word]
        elif word in UNITS:
            total += UNITS[word]
    return total

# %%
# ---------- STEP 1: Download Arabic PDF ----------
def download_pdf(url, path):
    if not os.path.exists(path):
        print(f"📥 Downloading {url} ...")
        r = requests.get(url)
        with open(path, "wb") as f:
            f.write(r.content)
        print("✅ PDF downloaded")

# %%
download_pdf(AR_URL, AR_PDF)

# %%
# ---------- STEP 2: Improved Text Extraction ----------
def extract_text_by_page(pdf_path):
    """Use PyMuPDF blocks extraction to keep Arabic order stable."""
    doc = fitz.open(pdf_path)
    texts = []
    for page in doc:
        blocks = page.get_text("blocks")
        blocks.sort(key=lambda b: (b[1], -b[0]))  # sort top-to-bottom, right-to-left
        page_text = "\n".join(b[4] for b in blocks)
        texts.append(page_text)
    return "\n".join(texts)

# %%
ar_text = extract_text_by_page(AR_PDF)

# %%
# ------------------------------------------------------
# 2️⃣  Split Level 3 — Articles (lowest level)
# ------------------------------------------------------

# %%
# ---------- STEP 4: Split Articles ----------
def split_articles(text: str):
    # Start-of-line ^ + 'المادة ... :'   (non-greedy body)   until next start-of-line 'المادة ... :' or EOF
    pattern = r"^\s*(المادة\s+([^:\n]{1,80})\s*:\s*(.*?))(?=^\s*المادة\s+[^:\n]{1,80}\s*:|\Z)"
    matches = re.findall(pattern, text, flags=re.DOTALL | re.MULTILINE)

    articles = []
    for idx, match in enumerate(matches, start=1):
        full_match, number_text, article_content = match
        number_text = number_text.strip()
        article_content = article_content.strip()
        number_value = arabic_text_to_number(number_text)
        articles.append({
            "article_number": number_value,
            "arabic_name": f"المادة {number_text}",
            "number_ar": number_text,
            "arabic_content": article_content
        })
    return articles

# %%
# ------------------------------------------------------
# 3️⃣  Split Level 2 — Chapters (each chapter contains articles)
# ------------------------------------------------------

# %%
# ---------- STEP 5: Split Chapters ----------
def split_chapters(text: str):
    chapter_pattern = r"(الفصل\s+[^\n]{1,30})\s*\n\s*([^\n]*)"
    matches = list(re.finditer(chapter_pattern, text))
    chapters = []
    if not matches:
        chapters.append({
            "chapter_title_ar": "بدون فصل",
            "chapter_number_ar" : None,
            "chapter_number": None,
            "text": text
        })
        return chapters
    for i, match in enumerate(matches):
        start = match.start()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        chapter_header = match.group(1).strip()
        chapter_title = match.group(2).strip()
        chapter_number = chapter_header.replace("الفصل", "").strip()
        number_value = arabic_text_to_number(chapter_number)
        chapter_text = text[start:end]
        chapters.append({
            "chapter_title_ar": chapter_title,
            "chapter_number_ar": chapter_number,
            "chapter_number": number_value,
            "text": chapter_text
        })
    return chapters

# %%
# ------------------------------------------------------
# 4️⃣  Split Level 1 — Parts (each part contains chapters)
# ------------------------------------------------------

# %%
# ---------- STEP 6: Split Parts ----------
def split_parts(text: str):
    part_pattern = r"(الباب\s+[^\n]{1,30})\s*\n\s*([^\n]*)"
    matches = list(re.finditer(part_pattern, text))
    parts = []
    if not matches:
        parts.append({
            "part_title_ar": "الجزء العام",
            "part_number_ar": None,
            "part_number": None,
            "text": text
        })
        return parts
    for i, match in enumerate(matches):
        start = match.start()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        part_header = match.group(1).strip()
        part_title = match.group(2).strip()
        part_number = part_header.replace("الباب", "").strip()
        number_value = arabic_text_to_number(part_number)
        part_text = text[start:end]
        parts.append({
            "part_title_ar": part_title,
            "part_number_ar": part_number,
            "part_number": number_value,
            "text": part_text
        })
    return parts

# %%
# ------------------------------------------------------
# 5️⃣  Main Aggregation — Combine all levels
# ------------------------------------------------------

# %%
# ---------- STEP 7: Combine All ----------
def extract_structure(text: str):
    result = []
    parts = split_parts(text)
    index = 0
    for part in parts:
        part_title_ar = part["part_title_ar"]
        part_number_ar = part["part_number_ar"]
        part_number = part["part_number"]
        chapters = split_chapters(part["text"])
        
        for chapter in chapters:
            chapter_title_ar = chapter["chapter_title_ar"]
            chapter_number_ar = chapter["chapter_number_ar"]
            chapter_number = chapter["chapter_number"]
            articles = split_articles(chapter["text"])
            for art in articles:
                index +=1
                result.append({
                    "index": index,
                    "part_title_ar": part_title_ar,
                    "part_number_ar": part_number_ar,
                    "part_number": part_number,
                    "chapter_title_ar": chapter_title_ar,
                    "chapter_number_ar": chapter_number_ar,
                    "chapter_number": chapter_number,
                    "arabic_name": art["arabic_name"],
                    "article_number": art["article_number"],
                    "number_ar": art["number_ar"],
                    "arabic_content": art["arabic_content"]
                })
    return result

# %%
print("🔍 Parsing structure ...")
articles_data = extract_structure(ar_text)
print(f"✅ Articles detected: {len(articles_data)}")
# Out:
# 🔍 Parsing structure ...
# ✅ Articles detected: 249

# %%
# ------------------------------------------------------
# 7️⃣ Translation setup (your better version)
# ------------------------------------------------------
print("🌐 Loading translation model...")
model_name = "Helsinki-NLP/opus-mt-ar-en"
tokenizer = MarianTokenizer.from_pretrained(model_name)
translator = MarianMTModel.from_pretrained(model_name)
# Out:
# 🌐 Loading translation model...

# %%
def translate_short(text):
    """Translate text safely within model's token limit."""
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=MAX_TOKENS)
    translated = translator.generate(**inputs, max_length=MAX_TOKENS)
    return tokenizer.decode(translated[0], skip_special_tokens=True)


def split_long_by_tokens(text, max_tokens=MAX_TOKENS):
    """Split a long text into smaller pieces based on tokens."""
    tokens = tokenizer(text).input_ids
    if len(tokens) <= max_tokens:
        return [text]
    
    # Reconstruct segments from tokens
    segments = []
    start = 0
    while start < len(tokens):
        end = min(start + max_tokens, len(tokens))
        segment_text = tokenizer.decode(tokens[start:end], skip_special_tokens=True)
        segments.append(segment_text)
        start = end
    return segments

def translate_long(text, max_tokens=MAX_TOKENS):
    """Split text by paragraphs, then by tokens if needed, and translate safely."""
    paragraphs = [p.strip() for p in re.split(r'\n{2,}', text) if p.strip()]
    chunks = []
    current_chunk = []
    current_len = 0

    for p in paragraphs:
        p_tokens = tokenizer(p).input_ids
        if len(p_tokens) > max_tokens:
            # Paragraph itself too long → split further
            for seg in split_long_by_tokens(p, max_tokens):
                chunks.append(seg)
            continue

        if current_len + len(p_tokens) > max_tokens:
            chunks.append("\n\n".join(current_chunk))
            current_chunk = [p]
            current_len = len(p_tokens)
        else:
            current_chunk.append(p)
            current_len += len(p_tokens)

    if current_chunk:
        chunks.append("\n\n".join(current_chunk))

    translated_parts = []
    for chunk in tqdm(chunks, desc="Translating", ncols=90):
        translated_parts.append(translate_short(chunk))

    return "\n\n".join(translated_parts)

# %%
# ------------------------------------------------------
# 8️⃣ Translate all Arabic articles
# ------------------------------------------------------
print("🚀 Translating articles...")
for art in tqdm(articles_data, desc="Translating"):
    art["english_content"] = translate_long(art["arabic_content"])
    art["english_number"] = f'Article {art["article_number"]}'
# Out:
# 🚀 Translating articles...
# Translating:   0%|                                                                             | 0/249 [00:00<?, ?it/s]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.41s/it]
# Translating:   0%|▎                                                                    | 1/249 [00:09<38:59,  9.44s/it]
# Translating:   0%|                                                  | 0/2 [00:00<?, ?it/s]
# Translating:  50%|█████████████████████                     | 1/2 [00:43<00:43, 43.32s/it]
# Translating: 100%|██████████████████████████████████████████| 2/2 [02:01<00:00, 60.62s/it]
# Translating:   1%|▌                                                                  | 2/249 [02:10<5:09:44, 75.24s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.23s/it]
# Translating:   1%|▊                                                                  | 3/249 [02:16<2:59:18, 43.73s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:02<00:00,  2.31s/it]
# Translating:   2%|█                                                                  | 4/249 [02:19<1:51:50, 27.39s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.50s/it]
# Translating:   2%|█▎                                                                 | 5/249 [02:29<1:26:38, 21.30s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.33s/it]
# Translating:   2%|█▌                                                                 | 6/249 [02:36<1:05:41, 16.22s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:33<00:00, 33.03s/it]
# Translating:   3%|█▉                                                                 | 7/249 [03:09<1:27:37, 21.73s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.43s/it]
# Translating:   3%|██▏                                                                | 8/249 [03:13<1:05:09, 16.22s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.41s/it]
# Translating:   4%|██▍                                                                  | 9/249 [03:20<52:38, 13.16s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.94s/it]
# Translating:   4%|██▋                                                                 | 10/249 [03:24<41:07, 10.32s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.65s/it]
# Translating:   4%|███                                                                 | 11/249 [03:29<35:18,  8.90s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.74s/it]
# Translating:   5%|███▎                                                                | 12/249 [03:33<28:58,  7.34s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.56s/it]
# Translating:   5%|███▌                                                                | 13/249 [03:39<26:45,  6.80s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.70s/it]
# Translating:   6%|███▊                                                                | 14/249 [03:54<37:12,  9.50s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.35s/it]
# Translating:   6%|████                                                                | 15/249 [03:56<27:30,  7.05s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:37<00:00, 37.18s/it]
# Translating:   6%|████▏                                                             | 16/249 [04:33<1:02:38, 16.13s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:31<00:00, 31.76s/it]
# Translating:   7%|████▌                                                             | 17/249 [05:05<1:20:34, 20.84s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.70s/it]
# Translating:   7%|████▊                                                             | 18/249 [05:14<1:07:21, 17.50s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:14<00:00, 14.31s/it]
# Translating:   8%|█████                                                             | 19/249 [05:29<1:03:25, 16.55s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.79s/it]
# Translating:   8%|█████▍                                                              | 20/249 [05:39<55:26, 14.52s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:14<00:00, 14.85s/it]
# Translating:   8%|█████▋                                                              | 21/249 [05:53<55:35, 14.63s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.76s/it]
# Translating:   9%|██████                                                              | 22/249 [05:57<43:02, 11.38s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:23<00:00, 23.61s/it]
# Translating:   9%|██████▎                                                             | 23/249 [06:21<56:42, 15.06s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.45s/it]
# Translating:  10%|██████▌                                                             | 24/249 [06:26<45:40, 12.18s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.52s/it]
# Translating:  10%|██████▊                                                             | 25/249 [06:35<41:24, 11.09s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:22<00:00, 22.24s/it]
# Translating:  10%|███████                                                             | 26/249 [06:57<53:41, 14.44s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:16<00:00, 16.60s/it]
# Translating:  11%|███████▎                                                            | 27/249 [07:14<55:51, 15.10s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:21<00:00, 21.68s/it]
# Translating:  11%|███████▍                                                          | 28/249 [07:35<1:02:55, 17.08s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:12<00:00, 12.18s/it]
# Translating:  12%|███████▉                                                            | 29/249 [07:48<57:16, 15.62s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:12<00:00, 12.18s/it]
# Translating:  12%|████████▏                                                           | 30/249 [08:00<53:16, 14.60s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:19<00:00, 19.21s/it]
# Translating:  12%|████████▍                                                           | 31/249 [08:19<58:05, 15.99s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.06s/it]
# Translating:  13%|████████▋                                                           | 32/249 [08:27<49:15, 13.62s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.36s/it]
# Translating:  13%|█████████                                                           | 33/249 [08:31<37:59, 10.55s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.41s/it]
# Translating:  14%|█████████▎                                                          | 34/249 [08:46<43:04, 12.02s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.82s/it]
# Translating:  14%|█████████▌                                                          | 35/249 [08:50<34:07,  9.57s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.32s/it]
# Translating:  14%|█████████▊                                                          | 36/249 [09:05<40:07, 11.30s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.54s/it]
# Translating:  15%|██████████                                                          | 37/249 [09:09<31:44,  8.98s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.28s/it]
# Translating:  15%|██████████▍                                                         | 38/249 [09:17<30:52,  8.78s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.83s/it]
# Translating:  16%|██████████▋                                                         | 39/249 [09:24<28:42,  8.20s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:26<00:00, 26.42s/it]
# Translating:  16%|██████████▉                                                         | 40/249 [09:50<47:38, 13.68s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.40s/it]
# Translating:  16%|███████████▏                                                        | 41/249 [10:02<45:05, 13.01s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.53s/it]
# Translating:  17%|███████████▍                                                        | 42/249 [10:05<35:05, 10.17s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.31s/it]
# Translating:  17%|███████████▋                                                        | 43/249 [10:10<28:54,  8.42s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.14s/it]
# Translating:  18%|████████████                                                        | 44/249 [10:21<31:35,  9.25s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:20<00:00, 20.54s/it]
# Translating:  18%|████████████▎                                                       | 45/249 [10:42<42:59, 12.64s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.86s/it]
# Translating:  18%|████████████▌                                                       | 46/249 [10:46<34:54, 10.32s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:17<00:00, 17.39s/it]
# Translating:  19%|████████████▊                                                       | 47/249 [11:04<41:54, 12.45s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:12<00:00, 12.14s/it]
# Translating:  19%|█████████████                                                       | 48/249 [11:16<41:25, 12.36s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.82s/it]
# Translating:  20%|█████████████▍                                                      | 49/249 [11:25<37:41, 11.31s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.19s/it]
# Translating:  20%|█████████████▋                                                      | 50/249 [11:36<37:25, 11.28s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.68s/it]
# Translating:  20%|█████████████▉                                                      | 51/249 [11:41<30:43,  9.31s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:14<00:00, 14.22s/it]
# Translating:  21%|██████████████▏                                                     | 52/249 [11:55<35:26, 10.79s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:25<00:00, 25.23s/it]
# Translating:  21%|██████████████▍                                                     | 53/249 [12:20<49:26, 15.14s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.34s/it]
# Translating:  22%|██████████████▋                                                     | 54/249 [12:32<45:30, 14.00s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.07s/it]
# Translating:  22%|███████████████                                                     | 55/249 [12:43<42:27, 13.13s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:33<00:00, 33.74s/it]
# Translating:  22%|██████████████▊                                                   | 56/249 [13:17<1:02:08, 19.32s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:07<00:00,  7.78s/it]
# Translating:  23%|███████████████▌                                                    | 57/249 [13:24<50:46, 15.87s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:02<00:00,  2.70s/it]
# Translating:  23%|███████████████▊                                                    | 58/249 [13:27<37:57, 11.92s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:16<00:00, 16.00s/it]
# Translating:  24%|████████████████                                                    | 59/249 [13:43<41:39, 13.15s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.55s/it]
# Translating:  24%|████████████████▍                                                   | 60/249 [13:52<37:07, 11.78s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.80s/it]
# Translating:  24%|████████████████▋                                                   | 61/249 [14:02<35:06, 11.20s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:29<00:00, 29.94s/it]
# Translating:  25%|████████████████▉                                                   | 62/249 [14:32<52:28, 16.84s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.05s/it]
# Translating:  25%|█████████████████▏                                                  | 63/249 [14:38<42:11, 13.61s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:07<00:00,  7.97s/it]
# Translating:  26%|█████████████████▍                                                  | 64/249 [14:46<36:46, 11.93s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.60s/it]
# Translating:  26%|█████████████████▊                                                  | 65/249 [14:56<35:23, 11.54s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:29<00:00, 29.56s/it]
# Translating:  27%|██████████████████                                                  | 66/249 [15:26<51:43, 16.96s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [01:30<00:00, 90.48s/it]
# Translating:  27%|█████████████████▊                                                | 67/249 [16:56<1:58:22, 39.02s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.76s/it]
# Translating:  27%|██████████████████                                                | 68/249 [17:01<1:26:44, 28.75s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.10s/it]
# Translating:  28%|██████████████████▎                                               | 69/249 [17:07<1:05:53, 21.97s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.26s/it]
# Translating:  28%|███████████████████                                                 | 70/249 [17:16<53:17, 17.86s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.45s/it]
# Translating:  29%|███████████████████▍                                                | 71/249 [17:27<47:18, 15.95s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:12<00:00, 12.22s/it]
# Translating:  29%|███████████████████▋                                                | 72/249 [17:39<43:46, 14.84s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:29<00:00, 29.46s/it]
# Translating:  29%|███████████████████▉                                                | 73/249 [18:09<56:25, 19.23s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.04s/it]
# Translating:  30%|████████████████████▏                                               | 74/249 [18:24<52:27, 17.99s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:25<00:00, 25.44s/it]
# Translating:  30%|████████████████████▍                                               | 75/249 [18:49<58:41, 20.24s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:33<00:00, 33.38s/it]
# Translating:  31%|████████████████████▏                                             | 76/249 [19:23<1:09:45, 24.19s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.97s/it]
# Translating:  31%|█████████████████████                                               | 77/249 [19:32<56:17, 19.63s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:39<00:00, 39.64s/it]
# Translating:  31%|████████████████████▋                                             | 78/249 [20:11<1:13:05, 25.65s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.49s/it]
# Translating:  32%|█████████████████████▌                                              | 79/249 [20:21<58:57, 20.81s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:12<00:00, 12.04s/it]
# Translating:  32%|█████████████████████▊                                              | 80/249 [20:33<51:12, 18.18s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:12<00:00, 12.87s/it]
# Translating:  33%|██████████████████████                                              | 81/249 [20:46<46:28, 16.60s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:30<00:00, 30.28s/it]
# Translating:  33%|██████████████████████▍                                             | 82/249 [21:16<57:39, 20.72s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:21<00:00, 21.92s/it]
# Translating:  33%|██████████████████████▋                                             | 83/249 [21:38<58:20, 21.09s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:07<00:00,  7.24s/it]
# Translating:  34%|██████████████████████▉                                             | 84/249 [21:45<46:35, 16.94s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.98s/it]
# Translating:  34%|███████████████████████▏                                            | 85/249 [21:55<40:38, 14.87s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:27<00:00, 27.31s/it]
# Translating:  35%|███████████████████████▍                                            | 86/249 [22:23<50:32, 18.61s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.07s/it]
# Translating:  35%|███████████████████████▊                                            | 87/249 [22:34<44:09, 16.35s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.22s/it]
# Translating:  35%|████████████████████████                                            | 88/249 [22:44<38:57, 14.52s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.40s/it]
# Translating:  36%|████████████████████████▎                                           | 89/249 [22:55<35:26, 13.29s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.13s/it]
# Translating:  36%|████████████████████████▌                                           | 90/249 [23:05<32:43, 12.35s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:02<00:00,  2.88s/it]
# Translating:  37%|████████████████████████▊                                           | 91/249 [23:08<25:04,  9.52s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:27<00:00, 27.24s/it]
# Translating:  37%|█████████████████████████                                           | 92/249 [23:35<38:50, 14.84s/it]
# Translating:   0%|                                                  | 0/2 [00:00<?, ?it/s]
# Translating:  50%|█████████████████████                     | 1/2 [01:36<01:36, 96.83s/it]
# Translating: 100%|██████████████████████████████████████████| 2/2 [01:40<00:00, 50.21s/it]
# Translating:  37%|████████████████████████▋                                         | 93/249 [25:15<1:45:21, 40.52s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:29<00:00, 29.23s/it]
# Translating:  38%|████████████████████████▉                                         | 94/249 [25:45<1:35:57, 37.14s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.70s/it]
# Translating:  38%|█████████████████████████▏                                        | 95/249 [25:56<1:15:46, 29.52s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.57s/it]
# Translating:  39%|█████████████████████████▍                                        | 96/249 [26:12<1:04:37, 25.34s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.16s/it]
# Translating:  39%|██████████████████████████▍                                         | 97/249 [26:27<56:29, 22.30s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.72s/it]
# Translating:  39%|██████████████████████████▊                                         | 98/249 [26:43<51:10, 20.33s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.14s/it]
# Translating:  40%|███████████████████████████                                         | 99/249 [26:53<43:12, 17.29s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.80s/it]
# Translating:  40%|██████████████████████████▉                                        | 100/249 [27:04<38:07, 15.35s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.84s/it]
# Translating:  41%|███████████████████████████▏                                       | 101/249 [27:14<33:48, 13.71s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:07<00:00,  7.04s/it]
# Translating:  41%|███████████████████████████▍                                       | 102/249 [27:21<28:42, 11.72s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.97s/it]
# Translating:  41%|███████████████████████████▋                                       | 103/249 [27:31<27:15, 11.20s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:07<00:00,  7.15s/it]
# Translating:  42%|███████████████████████████▉                                       | 104/249 [27:38<24:09,  9.99s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.48s/it]
# Translating:  42%|████████████████████████████▎                                      | 105/249 [27:50<25:04, 10.45s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:13<00:00, 13.15s/it]
# Translating:  43%|████████████████████████████▌                                      | 106/249 [28:03<26:51, 11.27s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:14<00:00, 14.95s/it]
# Translating:  43%|████████████████████████████▊                                      | 107/249 [28:18<29:18, 12.38s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:28<00:00, 28.26s/it]
# Translating:  43%|█████████████████████████████                                      | 108/249 [28:46<40:19, 17.16s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:18<00:00, 18.02s/it]
# Translating:  44%|█████████████████████████████▎                                     | 109/249 [29:04<40:39, 17.42s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:18<00:00, 18.50s/it]
# Translating:  44%|█████████████████████████████▌                                     | 110/249 [29:23<41:08, 17.76s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.54s/it]
# Translating:  45%|█████████████████████████████▊                                     | 111/249 [29:33<35:51, 15.59s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.76s/it]
# Translating:  45%|██████████████████████████████▏                                    | 112/249 [29:43<31:37, 13.85s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.23s/it]
# Translating:  45%|██████████████████████████████▍                                    | 113/249 [29:48<25:32, 11.27s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:02<00:00,  2.18s/it]
# Translating:  46%|██████████████████████████████▋                                    | 114/249 [29:50<19:14,  8.55s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:13<00:00, 13.79s/it]
# Translating:  46%|██████████████████████████████▉                                    | 115/249 [30:04<22:37, 10.13s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.67s/it]
# Translating:  47%|███████████████████████████████▏                                   | 116/249 [30:10<19:30,  8.80s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:27<00:00, 27.97s/it]
# Translating:  47%|███████████████████████████████▍                                   | 117/249 [30:38<32:02, 14.56s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.99s/it]
# Translating:  47%|███████████████████████████████▊                                   | 118/249 [30:43<25:32, 11.70s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.42s/it]
# Translating:  48%|████████████████████████████████                                   | 119/249 [30:48<21:16,  9.82s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.51s/it]
# Translating:  48%|████████████████████████████████▎                                  | 120/249 [30:52<17:03,  7.93s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.45s/it]
# Translating:  49%|████████████████████████████████▌                                  | 121/249 [30:55<14:04,  6.60s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.11s/it]
# Translating:  49%|████████████████████████████████▊                                  | 122/249 [31:03<14:55,  7.05s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.16s/it]
# Translating:  49%|█████████████████████████████████                                  | 123/249 [31:09<13:37,  6.49s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:07<00:00,  7.03s/it]
# Translating:  50%|█████████████████████████████████▎                                 | 124/249 [31:16<13:52,  6.66s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.97s/it]
# Translating:  50%|█████████████████████████████████▋                                 | 125/249 [31:21<12:43,  6.16s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.48s/it]
# Translating:  51%|█████████████████████████████████▉                                 | 126/249 [31:25<11:36,  5.66s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.19s/it]
# Translating:  51%|██████████████████████████████████▏                                | 127/249 [31:30<11:13,  5.52s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.56s/it]
# Translating:  51%|██████████████████████████████████▍                                | 128/249 [31:39<12:58,  6.44s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.50s/it]
# Translating:  52%|██████████████████████████████████▋                                | 129/249 [31:40<09:55,  4.96s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:22<00:00, 22.47s/it]
# Translating:  52%|██████████████████████████████████▉                                | 130/249 [32:03<20:16, 10.22s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.52s/it]
# Translating:  53%|███████████████████████████████████▏                               | 131/249 [32:06<16:09,  8.21s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.30s/it]
# Translating:  53%|███████████████████████████████████▌                               | 132/249 [32:10<13:09,  6.74s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.07s/it]
# Translating:  53%|███████████████████████████████████▊                               | 133/249 [32:18<13:49,  7.15s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:13<00:00, 13.26s/it]
# Translating:  54%|████████████████████████████████████                               | 134/249 [32:31<17:13,  8.99s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:02<00:00,  2.34s/it]
# Translating:  54%|████████████████████████████████████▎                              | 135/249 [32:34<13:17,  7.00s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.57s/it]
# Translating:  55%|████████████████████████████████████▌                              | 136/249 [32:39<12:23,  6.58s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.68s/it]
# Translating:  55%|████████████████████████████████████▊                              | 137/249 [32:44<11:13,  6.01s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.24s/it]
# Translating:  55%|█████████████████████████████████████▏                             | 138/249 [32:47<09:35,  5.19s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.63s/it]
# Translating:  56%|█████████████████████████████████████▍                             | 139/249 [32:53<09:45,  5.33s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.57s/it]
# Translating:  56%|█████████████████████████████████████▋                             | 140/249 [33:02<12:00,  6.61s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.67s/it]
# Translating:  57%|█████████████████████████████████████▉                             | 141/249 [33:12<13:33,  7.53s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:11<00:00, 11.83s/it]
# Translating:  57%|██████████████████████████████████████▏                            | 142/249 [33:24<15:44,  8.83s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.31s/it]
# Translating:  57%|██████████████████████████████████████▍                            | 143/249 [33:32<15:20,  8.68s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.70s/it]
# Translating:  58%|██████████████████████████████████████▋                            | 144/249 [33:34<11:32,  6.59s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.22s/it]
# Translating:  58%|███████████████████████████████████████                            | 145/249 [33:42<12:16,  7.08s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:07<00:00,  7.22s/it]
# Translating:  59%|███████████████████████████████████████▎                           | 146/249 [33:49<12:14,  7.13s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.03s/it]
# Translating:  59%|███████████████████████████████████████▌                           | 147/249 [33:53<10:33,  6.21s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.59s/it]
# Translating:  59%|███████████████████████████████████████▊                           | 148/249 [33:58<09:38,  5.73s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:12<00:00, 12.83s/it]
# Translating:  60%|████████████████████████████████████████                           | 149/249 [34:11<13:06,  7.87s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:10<00:00, 10.73s/it]
# Translating:  60%|████████████████████████████████████████▎                          | 150/249 [34:22<14:24,  8.73s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.90s/it]
# Translating:  61%|████████████████████████████████████████▋                          | 151/249 [34:27<12:23,  7.59s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.04it/s]
# Translating:  61%|████████████████████████████████████████▉                          | 152/249 [34:28<09:03,  5.60s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.05it/s]
# Translating:  61%|█████████████████████████████████████████▏                         | 153/249 [34:29<06:44,  4.21s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.07s/it]
# Translating:  62%|█████████████████████████████████████████▍                         | 154/249 [34:37<08:30,  5.38s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# Translating:  62%|█████████████████████████████████████████▋                         | 155/249 [34:38<06:23,  4.08s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.59s/it]
# Translating:  63%|█████████████████████████████████████████▉                         | 156/249 [34:39<05:10,  3.34s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.71s/it]
# Translating:  63%|██████████████████████████████████████████▏                        | 157/249 [34:44<05:45,  3.75s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.86s/it]
# ...
# Translating:  79%|█████████████████████████████████████████████████████              | 197/249 [41:18<05:05,  5.88s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.04s/it]
# Translating:  80%|█████████████████████████████████████████████████████▎             | 198/249 [41:19<03:46,  4.43s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:13<00:00, 13.43s/it]
# Translating:  80%|█████████████████████████████████████████████████████▌             | 199/249 [41:33<05:56,  7.14s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# Translating:  80%|█████████████████████████████████████████████████████▊             | 200/249 [41:34<04:20,  5.31s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:23<00:00, 23.46s/it]
# Translating:  81%|██████████████████████████████████████████████████████             | 201/249 [41:57<08:36, 10.76s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.13s/it]
# Translating:  81%|██████████████████████████████████████████████████████▎            | 202/249 [42:04<07:20,  9.38s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.04s/it]
# Translating:  82%|██████████████████████████████████████████████████████▌            | 203/249 [42:19<08:29, 11.08s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.58s/it]
# Translating:  82%|██████████████████████████████████████████████████████▉            | 204/249 [42:28<07:58, 10.64s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.71s/it]
# Translating:  82%|███████████████████████████████████████████████████████▏           | 205/249 [42:32<06:16,  8.56s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.05s/it]
# Translating:  83%|███████████████████████████████████████████████████████▍           | 206/249 [42:33<04:31,  6.32s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.91s/it]
# Translating:  83%|███████████████████████████████████████████████████████▋           | 207/249 [42:38<04:07,  5.90s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.10it/s]
# Translating:  84%|███████████████████████████████████████████████████████▉           | 208/249 [42:39<03:00,  4.41s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.09it/s]
# Translating:  84%|████████████████████████████████████████████████████████▏          | 209/249 [42:40<02:14,  3.37s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.14it/s]
# Translating:  84%|████████████████████████████████████████████████████████▌          | 210/249 [42:41<01:42,  2.63s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.06it/s]
# Translating:  85%|████████████████████████████████████████████████████████▊          | 211/249 [42:42<01:20,  2.13s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.82s/it]
# Translating:  85%|█████████████████████████████████████████████████████████          | 212/249 [42:57<03:50,  6.24s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.07it/s]
# Translating:  86%|█████████████████████████████████████████████████████████▎         | 213/249 [42:58<02:47,  4.65s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.13it/s]
# Translating:  86%|█████████████████████████████████████████████████████████▌         | 214/249 [42:59<02:03,  3.53s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# Translating:  86%|█████████████████████████████████████████████████████████▊         | 215/249 [43:00<01:34,  2.78s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.10it/s]
# Translating:  87%|██████████████████████████████████████████████████████████         | 216/249 [43:01<01:13,  2.23s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.04it/s]
# Translating:  87%|██████████████████████████████████████████████████████████▍        | 217/249 [43:02<00:59,  1.85s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.05it/s]
# Translating:  88%|██████████████████████████████████████████████████████████▋        | 218/249 [43:03<00:49,  1.59s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.02it/s]
# Translating:  88%|██████████████████████████████████████████████████████████▉        | 219/249 [43:04<00:42,  1.41s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.03it/s]
# Translating:  88%|███████████████████████████████████████████████████████████▏       | 220/249 [43:05<00:37,  1.29s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.09s/it]
# Translating:  89%|███████████████████████████████████████████████████████████▍       | 221/249 [43:06<00:34,  1.23s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.06it/s]
# Translating:  89%|███████████████████████████████████████████████████████████▋       | 222/249 [43:07<00:31,  1.15s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:22<00:00, 22.82s/it]
# Translating:  90%|████████████████████████████████████████████████████████████       | 223/249 [43:30<03:19,  7.66s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# Translating:  90%|████████████████████████████████████████████████████████████▎      | 224/249 [43:31<02:21,  5.68s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.07it/s]
# Translating:  90%|████████████████████████████████████████████████████████████▌      | 225/249 [43:32<01:42,  4.26s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.08it/s]
# Translating:  91%|████████████████████████████████████████████████████████████▊      | 226/249 [43:33<01:15,  3.26s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.07it/s]
# Translating:  91%|█████████████████████████████████████████████████████████████      | 227/249 [43:34<00:56,  2.57s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.09it/s]
# Translating:  92%|█████████████████████████████████████████████████████████████▎     | 228/249 [43:35<00:43,  2.08s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.06s/it]
# Translating:  92%|█████████████████████████████████████████████████████████████▌     | 229/249 [43:36<00:35,  1.78s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.05it/s]
# Translating:  92%|█████████████████████████████████████████████████████████████▉     | 230/249 [43:37<00:29,  1.54s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:15<00:00, 15.96s/it]
# Translating:  93%|██████████████████████████████████████████████████████████████▏    | 231/249 [43:53<01:45,  5.87s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:09<00:00,  9.24s/it]
# Translating:  93%|██████████████████████████████████████████████████████████████▍    | 232/249 [44:02<01:57,  6.89s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.73s/it]
# Translating:  94%|██████████████████████████████████████████████████████████████▋    | 233/249 [44:08<01:44,  6.55s/it]
# Translating:   0%|                                                  | 0/2 [00:00<?, ?it/s]
# Translating:  50%|█████████████████████                     | 1/2 [00:06<00:06,  6.12s/it]
# Translating: 100%|██████████████████████████████████████████| 2/2 [00:17<00:00,  8.82s/it]
# Translating:  94%|██████████████████████████████████████████████████████████████▉    | 234/249 [44:26<02:28,  9.88s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.33s/it]
# Translating:  94%|███████████████████████████████████████████████████████████████▏   | 235/249 [44:29<01:50,  7.92s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.74s/it]
# Translating:  95%|███████████████████████████████████████████████████████████████▌   | 236/249 [44:33<01:26,  6.67s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:25<00:00, 25.79s/it]
# Translating:  95%|███████████████████████████████████████████████████████████████▊   | 237/249 [44:59<02:28, 12.42s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:08<00:00,  8.52s/it]
# Translating:  96%|████████████████████████████████████████████████████████████████   | 238/249 [45:07<02:03, 11.25s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:05<00:00,  5.20s/it]
# Translating:  96%|████████████████████████████████████████████████████████████████▎  | 239/249 [45:12<01:34,  9.44s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.07it/s]
# Translating:  96%|████████████████████████████████████████████████████████████████▌  | 240/249 [45:13<01:02,  6.90s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.10it/s]
# Translating:  97%|████████████████████████████████████████████████████████████████▊  | 241/249 [45:14<00:40,  5.10s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.10it/s]
# Translating:  97%|█████████████████████████████████████████████████████████████████  | 242/249 [45:15<00:26,  3.85s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.10it/s]
# Translating:  98%|█████████████████████████████████████████████████████████████████▍ | 243/249 [45:16<00:17,  2.97s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:00<00:00,  1.11it/s]
# Translating:  98%|█████████████████████████████████████████████████████████████████▋ | 244/249 [45:17<00:11,  2.36s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:01<00:00,  1.03s/it]
# Translating:  98%|█████████████████████████████████████████████████████████████████▉ | 245/249 [45:18<00:07,  1.97s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:34<00:00, 34.82s/it]
# Translating:  99%|██████████████████████████████████████████████████████████████████▏| 246/249 [45:53<00:35, 11.83s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:04<00:00,  4.79s/it]
# Translating:  99%|██████████████████████████████████████████████████████████████████▍| 247/249 [45:58<00:19,  9.72s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:06<00:00,  6.42s/it]
# Translating: 100%|██████████████████████████████████████████████████████████████████▋| 248/249 [46:04<00:08,  8.74s/it]
# Translating:   0%|                                                  | 0/1 [00:00<?, ?it/s]
# Translating: 100%|██████████████████████████████████████████| 1/1 [00:03<00:00,  3.83s/it]
# Translating: 100%|███████████████████████████████████████████████████████████████████| 249/249 [46:08<00:00, 11.12s/it]

# %%
# ---------- STEP 8: Save JSON (Arabic readable) ----------
with open(JSON_PATH, "w", encoding="utf-8") as f:
    json.dump(articles_data, f, ensure_ascii=False, indent=2)
print(f"✅ Saved parsed data → {JSON_PATH} ({len(articles_data)} articles)")
# Out:
# ✅ Saved parsed data → data/labor_law\labor_law_parsed.json (249 articles)

# %%
articles_data
# Out:
# [{'index': 1,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'التعريفات',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الأولى',
#   'article_number': 1,
#   'number_ar': 'الأولى',
#   'arabic_content': 'يسمى هذا النظام نظام العمل.'},
#  {'index': 2,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'التعريفات',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثانية',
#   'article_number': 2,
#   'number_ar': 'الثانية',
#   'arabic_content': '1 \n \nيقصد بالألفاظ والعبارات الآتية – أينما وردت في هذا النظام – المعاني المبينة أمامها ما لم يقتض السياق خلاف ذلك:  \n\n-الوزارة: وزارة الموارد البشرية والتنمية الاجتماعية.  \n\n-الوزير: وزير الموارد البشرية والتنمية الاجتماعية.  \n\n-مكتب العمل: الجهة الإدارية المنوط بها شؤون العمل في النطاق المكاني الذي يحدد بقرار من الوزير. \n\n-صاحب العمل: كل شخص طبيعي أو اعتباري يشغّل عاملاً أو أكثر مقابل أجر. \n\n-العامل: كل شخص طبيعي –ذكراً أو أنثى- يعمل لمصلحة صاحب عمل وتحت إدارته أو إشرافه مقابل أجر، ولو كان بعيداً عن نظارته. \n\n-الحدث: الشخص الذي أتم الخامسة عشرة من عمره ولم يبلغ الثامنة عشرة. \n\n-العمل: الجهد المبذول في النشاطات الإنسانية كافة، تنفيذاً لعقد عمل )مكتوب أو غير مكتوب( بصرف النظر عن طبيعتها أو نوعها، \n\nصناعية كانت أو تجارية، أو زراعية أو فنية، أو غيرها، عضلية كانت أو ذهنية. \n\n-العمل الأصلي: بالنسبة للأفراد: موضوع نشاطهم المعتاد، وبالنسبة للمنشآت: الأعمال التي أنشئت المنشأة من أجل القيام بها \nوالمنصوص عليها في عقد تأسيسها أو في عقد الامتياز – إن كانت من شركات الامتياز – أو في السجل التجاري. \n\n-العمل المؤقت: العمل الذي يدخل بطبيعته فيما يزاوله صاحب العمل من نشاط وتقتضي طبيعة إنجازه مدة محددة، أو ينصب على عمل \nبذاته وينتهي بانتهائه، ولا يتجاوز في الحالتين تسعين يوماً. \n\n-العمل العرضي: العمل الذي لا يدخل بطبيعته فيما يزاوله صاحب العمل في نشاطه المعتاد، ولا يستغرق تنفيذه أكثر من تسعين يوماً. \n\n-العمل الموسمي: العمل الذي يتم في مواسم دورية متعارف عليها. \n\n-العمل لبعض الوقت: العمل الذي يؤديه عامل غير متفرغ لدى صاحب عمل ولساعات عمل تقل عن نصف ساعات العمل اليومية \nالمعتادة لدى المنشأة، سواء كان هذا العامل يؤدي ساعات عمله يومياً أو بعض أيام الأسبوع. \n\n-الخدمة المستمرة: خدمة العامل غير المنقطعة مع صاحب العمل نفسه أو خلفه النظامي، من تاريخ ابتداء الخدمة. وتعد الخدمة \nمستمرة في الحالات الآتية:  \n\n \n\n1- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/ 134 ( وﺗﺎرﻳﺦ 27 / 11 / 1440 ﻫـ، وﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ . \n \n\n \n2 \n\n1.الإجازات والعطل المقررة نظاماً. \n\n2.فترة الانقطاع لأداء الامتحانات وفقاً لما هو منصوص عليه في هذا النظام. \n\n3.حالات غياب العامل عن عمله بدون أجر التي لا تزيد مدتها على عشرين يوماً متقطعة خلال سنة العمل. \n\n-الإسناد: خدمة توفير عامل للعمل لدى غير صاحب العمل وذلك من خلال منشأة مرخص لها لهذا الغرض. \n\n-الاستقالة: إفصاح العامل كتابة عن رغبته دون إكراه في إنهاء عقد عمل محدد المدة دون تعليق على قيد أو شرط، وقبول صاحب العمل \nبها. \n\n-الأجر الأساسـي: كل ما يعطى للعامل مقابل عمله، بموجب عقد عمل مكتوب أو غير مكتوب، مهما كان نوع الأجر أو طريقة أدائه، مضافاً \nإليه العلاوات الدورية. \n\n-الأجر الفعلي: الأجر الأساسي مضافاً إليه سائر الزيادات المستحقة الأخرى التي تتقرر للعامل مقابل جهد بذله في العمل، أو مخاطر يتعرض \nلها في أداء عمله، أو التي تتقرر للعامل لقاء العمل بموجب عقد العمل أو لائحة تنظيم العمل. ومن ذلك:  \n\n1- العمولة، أو النسبة المئوية من المبيعات، أو النسبة المئوية من الأرباح، التي تدفع مقابل ما يقوم بتسويقه، أو إنتاجه، أو تحصيله، أو ما \nيحققه من زيادة الإنتاج أو تحسينه. \n\n2- البدلات التي يستحقها العامل لقاء طاقة يبذلها، أو مخاطر يتعرض لها في أداء عمله. \n\n3- الزيادات التي قد تمنح وفقاً لمستوى المعيشة، أو لمواجهة أعباء العائلة. \n\n4- المنحة أو المكافأة: هي التي يعطيها صاحب العمل للعامل، وما يصرف له جزاء أمانته، أو كفايته، وما شابه ذلك، إذا كانت هذه المنحة \nأو المكافأة مقررة في عقد العمل، أو لائحة تنظيم العمل للمنشأة، أو جرت العادة بمنحها، حتى أصبح العمال يعدونها جزءاً من الأجر لا تبرعاً. \n\n5- الميزات العينية: هي التي يلتزم صاحب العمل بتوفيرها للعامل مقابل عمله، بالنص عليها في عقد العمل أو في لائحة تنظيم العمل. \nوتقدر بحد أقصى يعادل الأجر الأساسي لمدة شهرين عن كل سنة ما لم تقدر في عقد العمل أو لائحة تنظيم العمل بما يزيد على ذلك. \n\n-الأجر: الأجر الفعلي. \n\n-المنشأة: كل مشروع يديره شخص طبيعي، أو اعتباري، يشغًل عاملاً أو أكثر، لقاء أجر أياً كان نوعه. \n\n-الشهر: ثلاثون يوماً ما لم ينص على خلاف ذلك في عقد العمل أو في لائحة تنظيم العمل. \n\n-اللائحة: اللائحة التنفيذية لهذا النظام. \n\n \n\n \n\n \n\n \n\n \n \n \n \n \n \n\n \n3'},
#  {'index': 3,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الثالثة',
#   'article_number': 3,
#   'number_ar': 'الثالثة',
#   'arabic_content': '2 \nالعمـــــل حـــــق للمـــــواطن ، لا يجـــــوز لغيـــــره ممارســـــته إلا بعـــــد تـــــوافر الشـــــروط المنصـــــوص عليهـــــا فـــــي هـــــذا النظـــــام ، \nوالمواطنـــــون متســـــاوون فـــــي حـــــق العمـــــل دون أي تمييـــــز علـــــى أســـــاس الجـــــنس أو الإعاقـــــة أو الســـــن أو أي شـــــكل مـــــن \nأشكال التمييز الأخرى، سواءً أثناء أداء العمل أو عند التوظيف أو الإعلان عنه.'},
#  {'index': 4,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الرابعة',
#   'article_number': 4,
#   'number_ar': 'الرابعة',
#   'arabic_content': 'يجــــب علــــى صــــاحب العمــــل والعامــــل عنــــد تطبيــــق أحكــــام هــــذا النظــــام الإلتــــزام بمقتضــــيات أحكــــام الشــــريعة الإســــلامية \n.'},
#  {'index': 5,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الخامسة',
#   'article_number': 5,
#   'number_ar': 'الخامسة',
#   'arabic_content': '3 \nتسري أحكام هذا النظام على الآتي:  \n1. كل عقد عمل يلتزم بمقتضاه أي شخص بالعمل لمصلحة صاحب عمل وتحت إدارته أو إشرافه ؛ مقابل أجر. \n2. عمال الحكومة والهيئات والمؤسسات العامة ، بمن فيهم الذين يشتغلون في المراعي أو الزراعة . \n3. عمال المؤسسات الخيرية . \n4. عقود التأهيل والتدريب مع غير العاملين لدى صاحب العمل في حدود الأحكام الخاصة المنصوص عليها في هذا النظام . \n5. العاملين بعض الوقت في حدود ما يتعلق بالسلامة والصحة المهنية وإصابات العمل وما يقرره الوزير .'},
#  {'index': 6,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة السادسة',
#   'article_number': 6,
#   'number_ar': 'السادسة',
#   'arabic_content': 'تســري على العامل العرضــي والموســمي والمؤقت الأحكام الخاصــة بالواجبات وقواعد التأديب ، والحد الأقصــى لســاعات العمل ، وفترات \nالراحة اليومية والراحة الأســـبوعية ، والتشـــغيل الإضـــافي ، والعطلات الرســـمية ، وقواعد الســـلامة ، والصـــحة المهنية ، وإصـــابات العمل \nوالتعويض عنها ، وما يقرره الوزير .'},
#  {'index': 7,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة السابعة',
#   'article_number': 7,
#   'number_ar': 'السابعة',
#   'arabic_content': '4 \n\n1- يستثنى من تطبيق أحكام هذا النظام كل من: \n\n أ- أفراد أسرة صاحب العمل، وهم زوجه وأصوله وفروعه الذين يعملون في المنشأة التي لا تضم سواهم. \n\nب- لاعبو الأندية والاتحادات الرياضية ومدربوها. \n\nج- العمالة المنزلية ومن في حكمهم. \n\nد- عمال الزراعة والرعاة الخاصون ومن في حكمهم. \n\n ه- العاملون غير السعوديين القادمون لأداء مهمة محددة ولمدة لا تزيد على شهرين. \n\n2- يصدر الوزير -بالتنسيق مع الجهات المختصة- لائحة أو أكثر للفئات الواردة في الفقرات الفرعية )أ( و)ج( و)د( و)ه( من الفقرة )1( من هذه \nالمادة؛ تشتمل على الحقوق والواجبات والأحكام الخاصة الأخرى ذات الصلة بكل فئة. واستثناء من حكم الفقرة )1( من هذه المادة؛ تطبَّق \nفي شأن مخالفات أحكام تلك اللوائح العقوبات المنصوص عليها في المادة )التاسعة والعشرين بعد المائتين( من هذا النظام. \n\n \n3- يُراعى أن تُضمَّن في اللوائح الصادرة في شأن الفئتين الواردتين في الفقرتين الفرعيتين )ج( و)د( من الفقرة )1( من هذه المادة الإجراءات \nوالآليات التي تكفل تحسين أداء سوق العمالة للفئتين، وتنظيم حركة انتقالها، وتحديد المسؤوليات والواجبات التي تترتب على أصحاب \nالعمل والمكاتب والشركات التي تقوم بالوساطة في التعاقد معها. \n\n \n\n2- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/134( وﺗﺎرﻳﺦ 27/11/1440ﻫـ. \n3- ﻋﺪﻟﺖ   ﻫﺬه اﳌﺎدة ﺑﻨﺎءً�  ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n4- ﻋﺪﻟﺖ  ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ .، وﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ . \n \n \n\n \n4'},
#  {'index': 8,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الثامنة',
#   'article_number': 8,
#   'number_ar': 'الثامنة',
#   'arabic_content': 'يبطل كل شرط يخالف أحكام هذا النظام ، ويبطل كل إبراء ، أو مصالحة عن الحقوق الناشئة للعامل بموجب هذا النظام ، أثناء سريان عقد \nالعمل ، ما لم يكن أكثر فائدة للعامل.'},
#  {'index': 9,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة التاسعة',
#   'article_number': 9,
#   'number_ar': 'التاسعة',
#   'arabic_content': 'اللغة العربية هي الواجبة الإستعمال في البيانات والسجلات والملفات وعقود العمل وغيرها مما هو منصوص عليه في هذا النظام ، أو \nفي أي قرار صادر تطبيقاً لأحكامه ، وكذلك التعليمات التي يصدرها صاحب العمل لعماله . \n\nوإذا استعمل صاحب العمل لغة أجنبية إلى جانب اللغة العربية في أي من الحالات المذكورة ، فإن النص العربي هو المعتمد دون غيره .'},
#  {'index': 10,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة العاشرة',
#   'article_number': 10,
#   'number_ar': 'العاشرة',
#   'arabic_content': 'تحسب جميع المدد والمواعيد المنصوص عليها في هذا النظام بالتقويم الهجري ، مالم ينص في عقد العمل أو لائحة تنظيم العمل على \nخلاف ذلك .'},
#  {'index': 11,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الحادية عشرة',
#   'article_number': 11,
#   'number_ar': 'الحادية عشرة',
#   'arabic_content': '5 \nإذا عهد صاحب العمل لأي شخص طبيعي أو معنوي القيام بعمل من أعماله الأصلية , أو جزء منها ؛ وجب على الأخير أن يعطي عماله جميع \nالحقوق والمزايا التي يعطيها صاحب العمل الأصلي لعماله .'},
#  {'index': 12,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الحادية عشرة مكرر',
#   'article_number': 11,
#   'number_ar': 'الحادية عشرة مكرر',
#   'arabic_content': '6 \nمع عدم الإخلال بأحكام هذا النظام والأنظمة ذات العلاقة؛ للوزير أن يتخذ الإجراءات التي من شأنها أن تكفل تحسين أداء سوق العمل ، \nوتنظيم حركة انتقال الأيدي العاملة .'},
#  {'index': 13,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الثانية عشرة',
#   'article_number': 12,
#   'number_ar': 'الثانية عشرة',
#   'arabic_content': '7 \n1. تضــع الوزارة نموذجاً موحداً - أو أكثر - للائحة تنظيم العمل ، على أن يكون شــاملاً لقواعد تنظيم العمل وما يتصــل به من أحكام ، بما \n\nفي ذلك الأحكام المتعلقة بالميزات والأحكام الخاصة بالمخالفات والجزاءات التأديبية . \n\n2. تضع الوزارة ضوابط وآليات اعتماد لوائح تنظيم العمل .'},
#  {'index': 14,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الثالثة عشرة',
#   'article_number': 13,
#   'number_ar': 'الثالثة عشرة',
#   'arabic_content': '8 \n1. يلتزم كل صاحب عمل بإعداد لائحة لتنظيم العمل في منشأته وفق النموذج المعد من الوزارة ، ويجوز للوزير الاستثناء من ذلك .  \n2. يجوز لصـاحب العمل تضـمين اللائحة شـروطاً وأحكاماً إضـافية ، بما لا يتعارض مع أحكام هذا النظام ولائحته والقرارات الصـادرة تنفيذاً \n\nله . \n\n3. يجب على صـــاحب العمل أن يعلن لائحة تنظيم العمل وأي تعديل يطرأ عليها في مكان ظاهر في المنشـــأة أو أي وســـيلة أخرى تكفل \n\nعلم الخاضعين لها بأحكامها .'},
#  {'index': 15,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الرابعة عشرة',
#   'article_number': 14,
#   'number_ar': 'الرابعة عشرة',
#   'arabic_content': '9 \n)ملغـــــاة('},
#  {'index': 16,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الخامسة عشرة',
#   'article_number': 15,
#   'number_ar': 'الخامسة عشرة',
#   'arabic_content': 'على صاحب العمل عند بدء العمل في أي منشأة أن يبلغ مكتب العمل المختص كتابة بالبيانات الآتية:  \n4. إسم المنشأة ونوعها ومركزها ، والعنوان الذي توجه إليه المراسلات ، وأي معلومة يكون من شأنها سهولة الإتصال بالمنشأة . \n5. النشاط الإقتصادي المرخص له بمزاولته مع ذكر رقم السجل التجاري أو الترخيص وتاريخه ، وجهة إصداره ، وإرفاق صورة منه . \n6. عدد العمال المراد تشغيلهم في المنشأة . \n7. إسم مدير المنشأة المسؤول . \n8. أي بيانات أخرى تطلبها الوزارة . \n \n \n\n \n\n5- ﻋﺪﻟﺖ ﺑﺎﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n6- أﺿﻴﻔﺖ ﺑﺎﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n7- ﻋﺪﻟﺖ ﺑﺎﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n8- ﻋﺪﻟﺖ ﺑﻌﺪ دﻣﺢ�� اﳌﺎدة )اﻟﺮاﺑﻌﺔ ﻋﺸﺮة( ﻟﻬﺎ ﺑﺎﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n9- ﻋﺪﻟﺖ وأﻟﻐﻴﺖ ﺑﻌﺪ دﻣﺤٜﻬﺎ ﻣﻊ اﳌﺎدة )اﻟﺜﺎﻟﺜﺔ ﻋﺸﺮة( ﺑﺎﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n1 \n\n \n5'},
#  {'index': 17,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة السادسة عشرة',
#   'article_number': 16,
#   'number_ar': 'السادسة عشرة',
#   'arabic_content': '1. إذا لم يتمكن صـاحب العمل من ممارسـة العمل بنفسـه ، فعليه أن يعين مسـؤولاً يمثله في مكان العمل . وفي حالة تعدد الشـركاء أو \n\nالمديرين في المنشــأة يســمى أحدهم من المقيمين في مكان العمل ، يمثل صــاحب العمل ويكون مســؤولاً عن أي مخالفة لأحكام \nهذا النظام . \n\n2. على صـــاحـب العمـل أن يبلغ مكتـب العمـل المختص كتـابـة بـاســـم الشـــريـك أو المـدير ، وعليـه في حـالـة تغييره أن يبلغ المكتـب بـإســـم \n\nالشريك أو المدير الجديد خلال سبعة أيام على الأكثر من تولي هذا الأخير عمله . \n\n3. إذا لم يوجد شـخص معين بصـفة مدير مسـؤول للمنشـأة - او إذا لم يباشـر الشـخص المعين عمله – فإن من يقوم فعلاً بأعمال المدير \n\nأو صاحب العمل نفسه يعد مديراً مسؤولاً عن المنشأة . \n\nوفي كل الأحوال تبقى مسؤولية صاحب العمل قائمة بصفة أصلية .'},
#  {'index': 18,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة السابعة عشرة',
#   'article_number': 17,
#   'number_ar': 'السابعة عشرة',
#   'arabic_content': 'على صـــاحـب العمـل أن يحتفظ في مكـان العمـل بـالســـجلات والكشـــوف والملفـات التي تحـدد مـاهيتهـا ، والبيـانـات التي يجـب أن تتضـــمنهـا \nاللائحة . \nوعليه أن يضع في مكان ظاهر بموقع العمل جدولاً بمواعيد العمل ، وفترات الراحة ، ويوم الراحة الأسبوعي ، ومواعيد بدء كل نوبة وإنتهائها \nفي حالة العمل بأسلوب المناوبة .'},
#  {'index': 19,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الثامنة عشرة',
#   'article_number': 18,
#   'number_ar': 'الثامنة عشرة',
#   'arabic_content': 'إذا انتقلت ملكية المنشأة لمالك جديد، أو طرأ تغيير على شكلها النظامي بالدمج أو التجزئة أو غير ذلك، تبقى عقود العمل نافذة في \nالحالين، وتعد الخدمة مستمرة. \nأما بالنســـبة لحقوق العمال الناشـــئة عن المدة الســـابقة لهذا التغيير من أجور، أو مكافأة نهاية خدمة مفترضـــة الاســـتحقاق بتاريخ انتقال \nالملكية، أو غير ذلك من حقوق؛ فيكون الخلف والسلف مسؤولين عنها بالتضامن. ويجوز في حال انتقال المنشآت الفردية لأي سبب اتفاق \nالســـلف والخلف على انتقـال جميع حقوق العمـال الســـابقـة إلى المـالـك الجـديـد بموافقـة العـامـل الخطيـة. وللعـامـل في حـال عـدم موافقتـه \nطلب إنهاء عقده وتسلّم مستحقاته من السلف.'},
#  {'index': 20,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة التاسعة عشرة',
#   'article_number': 19,
#   'number_ar': 'التاسعة عشرة',
#   'arabic_content': 'تعد المبالغ المسـتحقة للعامل أو ورثته بمقتضـى هذا النظام ديوناً ممتازة من الدرجة الأولى . وللعامل وورثته في سـبيل إسـتيفائها إمتياز \nعلى جميع أموال صـاحب العمل. وفي حالة إفلاس صـاحب العمل أو تصـفية منشـأته تسـجل المبالغ المذكورة ديوناً ممتازة، ويدفع للعامل \nمبلغ معجل يعادل أجر شهر واحد ، وذلك قبل سداد أي مصروف آخر - بما في ذلك المصروفات القضائية ومصروفات الإفلاس أو التصفية.'},
#  {'index': 21,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة العشرون',
#   'article_number': 20,
#   'number_ar': 'العشرون',
#   'arabic_content': 'لا يجوز لصـاحب العمل أو العامل أن يقوم بعمل من شـأنه إسـاءة اسـتعمال أحكام هذا النظام أو القرارات واللوائح الصـادرة تنفيذاً لأحكامه \nكما لايجوز لأي منهما القيام بعمل من شـأنه الضـغط على حرية الآخر أو حرية عمال أو اصـحاب عمل آخرين لتحقيق أي مصـلحة أو وجهة نظر \nيتبناها مما يتنافى مع حرية العمل أو إختصاص الجهة المختصة بتسوية الخلافات.'},
#  {'index': 22,
#   'part_title_ar': 'التعريفات والأحكام العامة',
#   'part_number_ar': 'الأول',
#   'part_number': 1,
#   'chapter_title_ar': 'الأحكام العامة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الحادية والعشرون',
#   'article_number': 21,
#   'number_ar': 'الحادية والعشرون',
#   'arabic_content': 'على الوزير – في سبيل تنفيذ أحكام هذا النظام – التنسيق مع الجهات ذات العلاقة كلما اقتضى الأمر ذلك. \n \n \n \n \n \n \n \n \n \n \n \n\n \n\n \n\n \n6 \n\n \n \n \n\n \n \n\n \n\n02'},
#  {'index': 23,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'قنوات التوظيف',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثانية والعشرون',
#   'article_number': 22,
#   'number_ar': 'الثانية والعشرون',
#   'arabic_content': '10 \nتوفر الوزارة قنوات للتوظيف دون مقابل، تقوم بما يأتي: \n\n1. مساعدة العمال في الحصول على الأعمال المناسبة، ومساعدة أصحاب الأعمال في إيجاد العمال المناسبين. \n2. جمع المعلومات الضرورية عن سوق العمل وتطوره وتحليلها؛ لكي تكون في متناول مختلف الهيئات العامة والخاصة المعنية \nبشؤون التخطيط الاقتصادي والاجتماعي.   \n3. تنفيذ الواجبات الآتية: \n3/1- تسجيل طالبي العمل.  \n3/2- الحصول على بيانات بالأعمال الشاغرة من أصحاب الأعمال.  \n3/3-مواءمة طلبات طالبي العمل مع الأعمال الشاغرة وفق مؤهلاتهم. \n3/4- تقديم النصح والمعونة إلى طالبي العمل فيما يختص بالتأهيل والتدريب المهني، أو بإعادة التدريب اللازم للحصول على \nالأعمال الشاغرة.  \n3/5- غير ذلك من الأمور التي تقررها الوزارة.'},
#  {'index': 24,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'قنوات التوظيف',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثالثة والعشرون',
#   'article_number': 23,
#   'number_ar': 'الثالثة والعشرون',
#   'arabic_content': '11 \nلكل مواطن في سن العمل قادر على العمل وراغب فيه أن يطلب قيد اسمه في قنوات التوظيف ، مع بيان تاريخ مولده ومؤهلاته وأعماله \nالسابقة ورغباته وعنوانه.'},
#  {'index': 25,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'قنوات التوظيف',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الرابعة والعشرون',
#   'article_number': 24,
#   'number_ar': 'الرابعة والعشرون',
#   'arabic_content': '12 \nتحدد اللائحة قواعد سير العمل وإجراءاته في قنوات التوظيف، ونماذج السجلات والإشعارات والأوراق المستخدمة في أعمالها ، وكذلك \nجداول تصنيف المهن وفقاً للتصنيف المهني المعتمد ، وتكون أساساً في تنظيم عمليات التوظيف .'},
#  {'index': 26,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'قنوات التوظيف',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الخامسة والعشرون',
#   'article_number': 25,
#   'number_ar': 'الخامسة والعشرون',
#   'arabic_content': '13 \nعلى كل صاحب عمل أن يرسل إلى الوزارة ما يأتي : \n1. بياناً بالأعمال الشـاغرة والمسـتحدثة ، وأنواعها ، ومكانها ، والأجر المخصـص لها ، والشـروط اللازم  توافرها لشـغلها ، وذلك في مدة لا \n\nتتجاوز خمسة عشر يوماً من تاريخ شغورها أو استحداثها . \n\n2. إشعاراً بما اتخذه  بشأن توظيف المواطن الذي رشحته قنوات التوظيف خلال سبعة أيام من تاريخ تسلّم خطاب الترشيح . \n3. بياناً بأسـماء عماله ، ووظائفهم ، ومهنهم ، وأجورهم ، وأعمارهم ، وجنسـياتهم ، وأرقام رخص العمل لغير السـعوديين وتواريخها وغير \n\nذلك من البيانات التي تحددها اللائحة . \n\n4. تقريراً عن حالة العمل وظروفه وطبيعته ، والنقص والزيادة في الأعمال المتوقعة خلال السنة التالية لتاريخ التقرير. \n5. ترسل البيانات المشار إليها في الفقرتين 3، 4 من هذه المادة خلال شهر محرم من كل عام.'},
#  {'index': 27,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'قنوات التوظيف',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة السادسة والعشرون',
#   'article_number': 26,
#   'number_ar': 'السادسة والعشرون',
#   'arabic_content': '1. على جميع المنشـــآت في مختلف أنشـــطتها ، وأياً كان عدد العاملين فيها ، العمل على إســـتقطاب الســـعوديين وتوظيفهم ، وتوفير \n\nوســائل اســتمرارهم في العمل ، وإتاحة الفرصــة المناســبة لهم لإثبات صــلاحيتهم للعمل عن طريق توجيههم وتدريبهم وتأهيلهم \nللأعمال الموكولة إليهم . \n\n2. يجب الاّ تقل  نســب العمال الســعوديين الذين  يســتخدمهم  صــاحب العمل  عن 75 % من مجموع عماله وللوزير في حالة عدم توافر \n\nالكفايات الفنية أو المؤهلات الدراسية ، أو تعذر إشغال الوظائف بالمواطنين أن يخفض هذه النسبة مؤقتاً.'},
#  {'index': 28,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'قنوات التوظيف',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة السابعة والعشرون',
#   'article_number': 27,
#   'number_ar': 'السابعة والعشرون',
#   'arabic_content': '14 \nللوزير عند الاقتضـــاء أن يلزم أصـــحاب العمل – في بعض النشـــاطات والمهن وفي بعض المناطق والمحافظات – بعدم توظيف العمال إلا \nبعد تسجيلهم في قنوات التوظيف بالشروط والأوضاع التي يحددها بقرار منه. \n\n \n\n10- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n11- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n12- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n13- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n14- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n\n \n8'},
#  {'index': 29,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'توظيف ذوي الإعاقة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الثامنة والعشرون',
#   'article_number': 28,
#   'number_ar': 'الثامنة والعشرون',
#   'arabic_content': '15 \nعلى كل صـاحب عمل يسـتخدم خمسـة وعشـرين عاملاً فأكثر، وكانت طبيعة العمل لديه تمكنه من تشـغيل ذوي الإعاقة الذين تم تأهيلهم \nمهنيًّا أن يشـغل 4% على الأقل من مجموع عدد عماله من ذوي الإعاقة المؤهلين مهنيًّا، سـواء أكان ذلك عن طريق ترشـيح قنوات التوظيف \nأو غيرها.   \nوعليه أن يرسل إلى الوزارة بيانًا بعدد الوظائف والأعمال التي يشغلها ذوو الإعاقة الذين تم تأهيلهم مهنيًّا، وأجر كل منهم.'},
#  {'index': 30,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'توظيف ذوي الإعاقة',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة التاسعة والعشرون',
#   'article_number': 29,
#   'number_ar': 'التاسعة والعشرون',
#   'arabic_content': 'إذا أصــيب أي عامل إصــابة عمل نتج عنها نقص في قدراته المعتادة لا يمنعه من أداء عمل آخر غير عمله الســابق، فإن على صــاحب العمل \nالـذي وقعـت إصـــابـة العـامـل بســـبـب العمـل لـديـه توظيفـه في العمـل المنـاســـب بـالأجر المحـدد لهـذا العمـل. ولا يخـل هـذا بمـا يســـتحقـه من \nتعويض عن إصابته. \n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n15- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n \n\n \n9'},
#  {'index': 31,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'المكاتب والشركات الأهلية لتوظيف السعوديين،',
#   'chapter_number_ar': 'الثالث',
#   'chapter_number': 3,
#   'arabic_name': 'المادة الثلاثون',
#   'article_number': 30,
#   'number_ar': 'الثلاثون',
#   'arabic_content': '16 \n1- لا يجوز لأي شـخص طبيعي أو اعتباري أن يمارس نشـاط توظيف السـعوديين أو نشـاط اسـتقدام العمال أو نشـاط الإسـناد ما لم يكن مرخصـاً \nله بذلك من الوزارة. \nوتحدد اللائحة ضـــوابط ممارســـة كل من هذه الأنشـــطة، وشـــروط منح الترخيص لكل منها وتجديده، والتزامات المرخص له، وقواعد عدم \nتجديد الترخيص أو إلغائه، والآثار المترتبة على ذلك، وغير ذلك مما يكون ضروريًّا من الشروط والضوابط لضمان حسن سير العمل بها.  \n2- تقترح الوزارة قيمة رســوم ممارســة الأنشــطة المشــار إليها في الفقرة )1( من هذه المادة، وأوجه صــرفها، تمهيداً لاســتكمال الإجراءات \nالنظامية في هذا الشأن".'},
#  {'index': 32,
#   'part_title_ar': 'تنظيم عمليات التوظيف',
#   'part_number_ar': 'الثاني',
#   'part_number': 2,
#   'chapter_title_ar': 'المكاتب والشركات الأهلية لتوظيف السعوديين،',
#   'chapter_number_ar': 'الثالث',
#   'chapter_number': 3,
#   'arabic_name': 'المادة الحادية والثلاثون',
#   'article_number': 31,
#   'number_ar': 'الحادية والثلاثون',
#   'arabic_content': '17 \nيُعدّ العمال الســعوديون الذين أســهمت المكاتب أو الشــركات في توظيفهم، والعمال الذين إســتقدمتهم نيابة عن أصــحاب العمل؛ عمالاً \nلدى صاحب العمل، ويرتبطون به بعلاقة عقدية مباشرة.   \n\n \n\n16- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n\n71- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n\n \n10 \n\n \n \n \n \n\n \n\n \n\n03'},
#  {'index': 33,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثانية والثلاثون',
#   'article_number': 32,
#   'number_ar': 'الثانية والثلاثون',
#   'arabic_content': 'لا يجوز الإستقدام بقصد العمل إلا بعد موافقة الوزارة .'},
#  {'index': 34,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثالثة والثلاثون',
#   'article_number': 33,
#   'number_ar': 'الثالثة والثلاثون',
#   'arabic_content': 'لا يجوز لغير الســـعودي أن يمارس عملاً ، ولا يجوز أن يســـمح له بمزاولته ، إلا بعد الحصـــول على رخصـــة عمل من الوزارة وفق النموذج الذي \nتعده لهذا الغرض . ويشترط لمنح الرخصة ما يأتي : \n1. أن يكون العامل قد دخل البلاد بطريقة مشروعة ومصرحاً له بالعمل . \n2. أن يكون من ذوي الكفـايـات المهنيـة أو المؤهلات الـدراســـيـة التي تحتـاج إليهـا البلاد، ولا يوجـد من أبنـاء البلاد من يحملهـا أو كـان العـدد \n\nالموجود منهم لا يفي بالحاجة، أو يكون من فئة العمال العاديين التي تحتاج إليها البلاد. \n\n3. أن يكون متعاقداً مع صاحب عمل وتحت مسؤوليته . \nويقصد بكلمة ) العمل ( في هذه المادة كل عمل صناعي أو تجاري أو زراعي أو مالي أو غيره وأي خدمة بما في ذلك الخدمة المنزلية .'},
#  {'index': 35,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الرابعة والثلاثون',
#   'article_number': 34,
#   'number_ar': 'الرابعة والثلاثون',
#   'arabic_content': 'لا يغني عن رخصة العمل المشار إليها أي تصريح أو ترخيص يكون مطلوباً من جهة أخرى لممارسة العمل أو المهنة .'},
#  {'index': 36,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الخامسة والثلاثون',
#   'article_number': 35,
#   'number_ar': 'الخامسة والثلاثون',
#   'arabic_content': '18 \nللوزارة -لاعتبارات تقدرها- أن تمتنع عن تجديد رخصة العمل متى خالف صاحب العمل المعايير الخاصة بتوطين الوظائف التي تضعها \nالوزارة، وأيًّا من الاشتراطات أو الضوابط الأخرى الواردة في اللائحة.  وتبين اللائحة الإجراءات التي تكفل عدم تأثر العامل من عدم تجديد \nرخصة العمل، بما في ذلك إمكانية نقل خدمة العامل إلى صاحب عمل آخر دون موافقة صاحب العمل المخالف.'},
#  {'index': 37,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة السادسة والثلاثون',
#   'article_number': 36,
#   'number_ar': 'السادسة والثلاثون',
#   'arabic_content': 'على الوزير أن يحدد بقرار منه المهن والأعمال التي يحظر على غير السعودي الاشتغال بها .'},
#  {'index': 38,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة السابعة والثلاثون',
#   'article_number': 37,
#   'number_ar': 'السابعة والثلاثون',
#   'arabic_content': '19 \nيجـب أن يكون عقـد عمـل غير الســـعودي مكتوبـاً ومحـدد المـدة. وإذا خلا العقـد من بيـان مـدتـه تعـد مـدتـه )ســـنـة( من تـاريخ مبـاشـــرة العـامـل \nالفعلية، وإذا استمر العمل بعد انتهاء هذه المدة، عُدَّ متجدداً لمدة مماثلة.'},
#  {'index': 39,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثامنة والثلاثون',
#   'article_number': 38,
#   'number_ar': 'الثامنة والثلاثون',
#   'arabic_content': 'لا يجوز لصـاحب العمل توظيف العامل  في مهنة  غير المهنة  المدونة في رخصـة عمله ،  ويحظر على العامل الاشـتغال في غير مهنته قبل \nاتخاذ الإجراءات النظامية لتغيير المهنة .'},
#  {'index': 40,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة التاسعة والثلاثون',
#   'article_number': 39,
#   'number_ar': 'التاسعة والثلاثون',
#   'arabic_content': '20 \nلا يجوز -بغير اتبـاع القواعـد والإجراءات النظـاميـة المقررة- أن يترك صـــاحـب العمـل عـاملـه يعمـل لـدى الغير أو يعمـل لحســـابـه الخـاص، ولا يجوز \nللعـامـل أن يعمـل لـدى صـــاحـب عمـل آخر أو لحســـابـه الخـاص، ولا يجوز لصـــاحـب العمـل توظيف عـامـل غيره، وتتولى الوزارة التفتيش على \nالمنشـــآت، وضـــبط مخـالفـات هـذا النظـام، واتخـاذ مـا يلزم لتطبيق العقوبـات المقررة بموجبـه، ومن ثم إحـالـة مـا يـدخـل في اختصـــاص وزارة \nالداخلية إليها لاتخاذ ما تراه وفق الأحكام المقررة نظامًا. كما تُحيل وزارة الداخلية -في حال ضــبطها مخالفات تتصــل بالأحكام المقررة لديها \nنظـامـاً- بيـانـات أصـــحـاب العمـل المخـالفين لحكم هـذه المـادة إلى وزارة الموارد البشـــريـة والتنميـة الاجتمـاعيـة؛ لتطبيق العقوبـات المقررة \nبموجب هذا النظام.'},
#  {'index': 41,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الأربعون',
#   'article_number': 40,
#   'number_ar': 'الأربعون',
#   'arabic_content': '21 \n1.  يتحمل صـاحب العمل رسـوم اسـتقدام العامل غير السـعودي، ورسـوم الإقامة ورخصـة العمل وتجديدهما، وما يترتب على تأخير ذلك \n\nمن غرامات يتســبب بها صــاحب العمل، ورســوم تغيير المهنة، والخروج والعودة، وتذكرة عودة العامل إلى موطنه بعد انتهاء العلاقة \nبين الطرفين. \n\n2. يتحمل العامل تكاليف عودته إلى بلده في حالة عدم صلاحيته للعمل أو إذا رغب في العودة دون سبب مشروع . \n3. يتحمل صاحب العمل رسوم نقل خدمات العامل الذي يرغب في نقل خدماته إليه . \n\n \n\n 18- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ ، وﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ . \n\n19- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n20- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/24( وﺗﺎرﻳﺦ 12/5/1434ﻫـ، وﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ . \n21- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n \n\n \n12 \n\n4.\n يلزم صـــاحـب العمـل بنفقـات تجهيز جثمـان العـامـل ونقلـه إلى الجهـة التي أبرم فيهـا العقـد أو اســـتقـدم العـامـل منهـا ، مـالم يـدفن \nبموافقة ذويه داخل المملكة . ويعفى صاحب العمل في حالة إلتزام المؤسسة العامة للتأمينات الاجتماعية بذلك .'},
#  {'index': 42,
#   'part_title_ar': 'توظيف غير السعوديين',
#   'part_number_ar': 'الثالث',
#   'part_number': 3,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الحادية والأربعون',
#   'article_number': 41,
#   'number_ar': 'الحادية والأربعون',
#   'arabic_content': 'تحدد اللائحة شروط الاستقدام، ونقل الخدمات ، وتغيير المهنة ، وضوابط ذلك وإجراءاته . \n \n \n \n \n\n \n\n \n\n \n\n \n\n \n\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n\n \n \n\n \n13 \n\n \n \n \n \n\n \n\n04'},
#  {'index': 43,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'التدريب والتأهيل للعاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثانية والأربعون',
#   'article_number': 42,
#   'number_ar': 'الثانية والأربعون',
#   'arabic_content': '22 \nعلــــى كــــل صــــاحب عمــــل وضــــع سياســــة لتــــدريب عمالــــه الســــعوديين وتــــأهيلهم، مــــن أجــــل رفــــع مهــــاراتهم وتحســــين \nمستواهم في الأعمال الفنية والإدارية والمهنية وغيرها. وتحدد اللائحة الأحكام المتصلة بذلك.'},
#  {'index': 44,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'التدريب والتأهيل للعاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثالثة والأربعون',
#   'article_number': 43,
#   'number_ar': 'الثالثة والأربعون',
#   'arabic_content': '23 \n\nدون إخلال بما تنص عليه اتفاقيات الامتياز وغيرها من الاتفاقيات من شروط وقواعد خاصة بالتدريب والتأهيل ورفع المهارات؛ على كل \nصاحب عمل أن يؤهل أو يدرب على أعماله من عماله السعوديين النسبة التي تُحدد بقرار من الوزير، ويدخل ضمن هذه النسبة العمال \n\nالسعوديون الذين يكملون دراساتهم إذا كان صاحب العمل يتحمل تكاليف الدراسة. وتحدد اللائحة المعايير والأحكام العامة المتصلة \nبذلك.'},
#  {'index': 45,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'التدريب والتأهيل للعاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الرابعة والأربعون',
#   'article_number': 44,
#   'number_ar': 'الرابعة والأربعون',
#   'arabic_content': '24 \nيجـــــب أن يشـــــتمل برنـــــامج التـــــدريب علـــــى المهـــــارة التـــــي يتـــــدرب العامـــــل عليهـــــا والقواعـــــد والشـــــروط التـــــي تتبـــــع فـــــي \nالتــــدريب، وعلــــى مدتــــه وعــــدد ســــاعاته والبــــرامج التدريبيــــة النظريــــة والعمليــــة، وطريقــــة الاختبــــار والشــــهادات التــــي تمــــنح \nفــــي هــــذا الشــــأن. وتحــــدد اللائحــــة المعــــايير والقواعــــد العامــــة التــــي ينبغــــي اتباعهــــا بهــــذا الخصــــوص لرفــــع مســــتوى أداء \nالعامل من حيث المهارة والإنتاجية. \n\n  \n\n \n\n22- عدلت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هـ \n\n 23- عدلت هذه المادة بناءً على المرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ ، وعدلت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هـ . \n\n24- عدلت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هـ \n\n \n15'},
#  {'index': 46,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'عقد التأهيل والتدريب مع غير العاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الخامسة والأربعون',
#   'article_number': 45,
#   'number_ar': 'الخامسة والأربعون',
#   'arabic_content': 'عقد التأهيل والتدريب عقد يلتزم بمقتضاه صاحب العمل بتأهيل أو تدريب شخص لإعداده في مهنة معينة.'},
#  {'index': 47,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'عقد التأهيل والتدريب مع غير العاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة السادسة والأربعون',
#   'article_number': 46,
#   'number_ar': 'السادسة والأربعون',
#   'arabic_content': '25 \n\nيجـــب أن يكـــون عقـــد التأهيـــل أو التـــدريب مكتوبـــًا، وأن يحـــدد فيـــه نـــوع المهنـــة المتعاقـــد للتـــدريب عليهـــا، ومـــدة التـــدريب ومراحلـــه \nالمتتابعــة، والمهــارة المســتهدف اكتســابها منــه، ومقــدار المكافــأة التــي تعطــى للمتــدرب فــي كــل مرحلــة، علــى ألا يكــون تحديــدها \nعلــى أســاس القطعــة أو الإنتــاج، ويجــب أن تُبــيَّن فــي العقــد حقــوق المتــدرب وصــاحب العمــل وواجباتهمــا، ومــا إذا كــان التأهيــل أو \nالتدريب في منشأة تتبع صاحب العمل أو لدى منشأة أخرى.'},
#  {'index': 48,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'عقد التأهيل والتدريب مع غير العاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة السابعة والأربعون',
#   'article_number': 47,
#   'number_ar': 'السابعة والأربعون',
#   'arabic_content': '26 \n\nللـــوزير أن يلـــزم المنشـــآت بقبـــول عـــدد أو نســـبة محـــددة مـــن طـــلاب الجامعـــات والكليـــات والمعاهـــد والمراكـــز وخريجيهـــا؛ بغيـــة \nالتـــدريب واســـتكمال الخبـــرة العمليـــة، وفـــق الشـــروط والأوضـــاع والمـــدد التـــي تحـــددها اللائحـــة، علـــى أن يُبـــرم عقـــد تـــدريب بـــين \nالمتدرب وصاحب العمل تطبق في شأنه الأحكام الواردة في هذا الفصل. وللمنشأة أن تقدم مكافأة للمتدرب.'},
#  {'index': 49,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'عقد التأهيل والتدريب مع غير العاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة الثامنة والأربعون',
#   'article_number': 48,
#   'number_ar': 'الثامنة والأربعون',
#   'arabic_content': '27  \n\n1. لصــاحب العمــل أن ينهــي عقــد التأهيــل أو التــدريب إذا ثبــت لــه عــدم قابليــة أو قــدرة المتــدرب أو الخاضــع للتأهيــل علــى إكمــال \n\nبـــرامج التـــدريب أو التأهيـــل بصـــورة مفيـــدة، وفقـــاً لتقـــارير تقـــويم دوريـــة تضـــعها المنشـــأة التـــي تقـــدم التـــدريب أو التأهيـــل. \nوللمتــدرب أو الخاضــع للتأهيــل الحــق فــي إنهــاء العقــد. وعلــى الطــرف الــذي يرغــب فــي إنهــاء العقــد إبــلاغ الطــرف الآخــر برغبتــه \nفــي ذلــك قبــل )أســبوع( علــى الأقــل مــن التــاريخ المحــدد للإنهــاء، ولــيس لأي مــن الطــرفين أن يطالــب الطــرف الآخــر بــالتعويض إلا \nإذا تضمن العقد حكماً يقضي بذلك. \n\n2. لصــاحب العمــل - بعــد إكمــال مــدة التــدريب أو التأهيــل - أن يلــزم المتــدرب أو الخاضــع للتأهيــل بــأن يعمــل لديــه مــدة مماثلــة \n\nلمــدة التــدريب أو التأهيــل ، فــإن رفــض أو امتنــع المتــدرب أو الخاضــع للتأهيــل عــن العمــل المــدة المماثلــة أو بعضــها ؛ وجــب \nعليه أن يدفع لصاحب العمل تكاليف التدريب أو التأهيل التي تحملها صاحب العمل أو بنسبة المدة الباقية منها .'},
#  {'index': 50,
#   'part_title_ar': 'التدريب والتأهيل',
#   'part_number_ar': 'الرابع',
#   'part_number': 4,
#   'chapter_title_ar': 'عقد التأهيل والتدريب مع غير العاملين لدى صاحب العمل',
#   'chapter_number_ar': 'الثاني',
#   'chapter_number': 2,
#   'arabic_name': 'المادة التاسعة والأربعون',
#   'article_number': 49,
#   'number_ar': 'التاسعة والأربعون',
#   'arabic_content': 'تسري على عقد التأهيل والتدريب الأحكام الواردة في هذا النظام ، الخاصة بالإجازات السنوية والعطلات الرسمية ، والحد الأقصى لساعات \nالعمل ، وفترات الراحة اليومية والراحة الأسبوعية ، وقواعد السلامة والصحة المهنية ، وإصابات العمل وشروطها ، وما يقرره الوزير. \n\n \n\n \n\n \n\n \n\n \n\n \n \n\n \n\n25- عدلت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هـ \n26- عدلت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هـ \n27- عدلت هذه المادة بناءً على المرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ ، وعدلت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هـ . \n\n \n16 \n\n \n \n \n \n \n\n \n\n05'},
#  {'index': 51,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الخمسون',
#   'article_number': 50,
#   'number_ar': 'الخمسون',
#   'arabic_content': 'عقد العمل هو عقد مبرم بين صاحب عمل وعامل ، يتعهد الأخير بموجبه أن يعمل تحت إدارة صاحب العمل أو إشرافه مقابل أجر .'},
#  {'index': 52,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الحادية والخمسون',
#   'article_number': 51,
#   'number_ar': 'الحادية والخمسون',
#   'arabic_content': '28 \n\nيجب أن يكتب عقد العمل من نسختين، يحتفظ كل من طرفيه بنسخة منه، ويجب توثيقه وفق الأحكام النظامية ذات الصلة وفي ضوء ما \nتحدده اللائحة، ويعد العقد قائمًا ولو كان غير مكتوب، وفي هذه الحالة يجوز للعامل وحده إثبات العقد وحقوقه التي نشأت عنه بجميع \nطرق الإثبات، ويكون لكل من الطرفين أن يطلب كتابة العقد في أي وقت. أما عمال الحكومة والمؤسسات العامة فيقوم قرار أو أمر \nالتعيين الصادر من الجهة المختصة مقام العقد.'},
#  {'index': 53,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثانية والخمسون',
#   'article_number': 52,
#   'number_ar': 'الثانية والخمسون',
#   'arabic_content': '29 \n\n1. مع مراعـاة مـا ورد في المـادة )الســـابعـة والثلاثين( من هـذا النظـام، تضـــع الوزارة نموذجـاً موحـداً لكـل نوع من أنواع عقـد العمـل، يحتوي \n\nبصـورة أسـاسـية على: اسـم صـاحب العمل ومكانه، واسـم العامل وجنسـيته، وما يلزم لإثبات شـخصـيته، وعنوان إقامته، والأجر المتفق \nعليـه بمـا في ذلـك المزايـا والبـدلات، ونوع العمـل ومكـانـه، وتـاريخ الالتحـاق بـه، ومـدة العقـد إن كـان محـدد المـدة، وحقوق كـل طرف \nوالتزاماته الأساسية. \n\n2. يجـب أن يكون عقـد العمـل وفق النموذج المشـــار إليـه في الفقرة )1( من هـذه المـادة، ولطرفي العقـد أن يضـــيفـا إليـه بنوداً أخرى ، بمـا لا \n\nيتعارض مع أحكام هذا النظام ولائحته والقرارات الصادرة تنفيذاً له .'},
#  {'index': 54,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثالثة والخمسون',
#   'article_number': 53,
#   'number_ar': 'الثالثة والخمسون',
#   'arabic_content': '30 \n\nإذا كان العامل خاضعاً للتجربة، وجب النص على ذلك صراحة في عقد العمل، وتحديد مدتها بوضوح، على ألا يزيد مجموع المدة في جميع \nالأحوال على )مائة وثمانين( يوماً. وتبين اللائحة الأحكام المتصلة بذلك بما في ذلك ما يتعلق بالإجازات التي لا تدخل في حساب المدة. \nولكل من الطرفين الحق في إنهاء العقد خلال هذه المدة.'},
#  {'index': 55,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الرابعة والخمسون',
#   'article_number': 54,
#   'number_ar': 'الرابعة والخمسون',
#   'arabic_content': '31 \n\nلا يجوز وضـع العامل تحت التجربة أكثر من مرة واحدة لدى صـاحب عمل واحد . واسـتثناء من ذلك يجوز باتفاق طرفي العقد - كتابة - إخضـاع \nالعامل لفترة تجربة أخرى بشـرط أن تكون في مهنة أخرى أو عمل آخر ، أو أن يكون قد مضـى على انتهاء علاقة العامل بصـاحب العمل مدة لا \nتقل عن سـتة أشـهر . وإذا أنهي العقد خلال فترة التجربة فإن أيًّا من الطرفين لا يسـتحق تعويضـاً ، كما لا يسـتحق العامل مكافأة نهاية الخدمة \nعن ذلك .'},
#  {'index': 56,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الخامسة والخمسون',
#   'article_number': 55,
#   'number_ar': 'الخامسة والخمسون',
#   'arabic_content': '32 \n\n1. ينتهي عقد العمل المحدد المدة بانقضاء مدته ، فإذا استمر طرفاه في تنفيذه عدّ العقد مجدداً لمدة غير محددة . مع مراعاة ما \n\nنصت عليه المادة )السابعة والثلاثون( من هذا النظام بالنسبة إلى غير السعوديين . \n\n2. إذا تضـــمن العقـد المحـدد المـدة شـــرطـاً يقضـــي بتجـديـده لمـدة ممـاثلـة أو لمـدة محـددة ، فـإنـه يتجـدد للمـدة المتفق عليهـا . فـإن تعـدد \n\nالتجديد ثلاث مرات متتالية ، أو بلغت مدة العقد الأصــلي مع مدة التجديد أربع ســنوات أيهما أقل واســتمر الطرفان في تنفيذه ؛ تحوّل \nالعقد إلى عقد غير محدد المدة . \n\n \n\n \n\n28- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ \n29- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ ، وﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ. \n30- ﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ، وﻋﺪﻟﺖ ﻫﺬه اﳌﺎدة ﺑﻨﺎءً� ﻋلى اﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/44( ﺑﺘﺎرﻳﺦ 8/2/1446ﻫـ. \n\n 31-ﻋﺪﻟﺖ ﺑﺎﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n\n32- ﻋﺪﻟﺖ ﺑﺎﳌﺮﺳﻮم اﳌﻠكى�� رﻗﻢ )م/46( وﺗﺎرﻳﺦ 5/6/1436ﻫـ . \n\n \n18'},
#  {'index': 57,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة السادسة والخمسون',
#   'article_number': 56,
#   'number_ar': 'السادسة والخمسون',
#   'arabic_content': 'في جميع الحالات التي يتجدد فيها العقد لمدة محددة ، تعد المدة التي تجدد إليها العقد امتداداً للمدة الأصلية في تحديد حقوق العامل \nالتي تدخل مدة الخدمة في حسابها .'},
#  {'index': 58,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة السابعة والخمسون',
#   'article_number': 57,
#   'number_ar': 'السابعة والخمسون',
#   'arabic_content': 'إذا كان العقد من أجل القيام بعمل معين ، فإنه ينتهي بإنجاز العمل المتفق عليه .'},
#  {'index': 59,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة الثامنة والخمسون',
#   'article_number': 58,
#   'number_ar': 'الثامنة والخمسون',
#   'arabic_content': '33 \n\n1. لا يجوز لصاحب العمل أن ينقل العامل بغير موافقته - كتابةً - من مكان عمله الأصلي إلى مكان آخر يقتضي تغيير محل إقامته . \n2. لصــاحب العمل - في حالات الضــرورة التي قد تقتضــيها ظروف عارضــة ولمدة لا تتجاوز ثلاثين يوماً في الســنة - تكليف العامل بعمل \n\nفي مكان يختلف عن المكان المتفق عليه دون اشــتراط موافقته ، على أن يتحمل صــاحب العمل تكاليف انتقال العامل وإقامته خلال \nتلك المدة.'},
#  {'index': 60,
#   'part_title_ar': 'علاقات العمل',
#   'part_number_ar': 'الخامس',
#   'part_number': 5,
#   'chapter_title_ar': 'عقد العمل',
#   'chapter_number_ar': 'الأول',
#   'chapter_number': 1,
#   'arabic_name': 'المادة التاسعة والخمسون',
#   'article_number': 59,
#   'number_ar': 'التاسعة والخمسون',
#   'arabic_content': 'لا يجوز نقـل العـامـل ذي الأجر الشـــهري إلى فئـة عمـال اليوميـة أو العمـال المعينين بـالأجر الأســـبوعي أو بـالقطعـة أو بـالســـاعـة ، إلا إذا وافق \nالعامل على ذلك كتابة ، ومع عدم الإخلال بالحقوق التي اكتسبها العامل في المدة التي قضاها بالأجر الشهري .'},
#  {'index': 61,
# ...
#   'arabic_name': 'المادة الحادية والعشرون بعد المائتين',
#   'article_number': 221,
#   'number_ar': 'الحادية والعشرون بعد المائتين',
#   'arabic_content': '87 \n)ملــــــغاة('},
#  {'index': 225,
#   'part_title_ar': 'هيئات تسوية الخلافات العمالية',
#   'part_number_ar': 'الرابع عشر',
#   'part_number': 4,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثانية والعشرون بعد المائتين',
#   'article_number': 222,
#   'number_ar': 'الثانية والعشرون بعد المائتين',
#   'arabic_content': '88 \n)ملــــــغاة('},
#  {'index': 226,
#   'part_title_ar': 'هيئات تسوية الخلافات العمالية',
#   'part_number_ar': 'الرابع عشر',
#   'part_number': 4,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثالثة والعشرون بعد المائتين',
#   'article_number': 223,
#   'number_ar': 'الثالثة والعشرون بعد المائتين',
#   'arabic_content': '89 \n)ملــــــغاة('},
#  {'index': 227,
#   'part_title_ar': 'هيئات تسوية الخلافات العمالية',
#   'part_number_ar': 'الرابع عشر',
#   'part_number': 4,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الرابعة والعشرون بعد المائتين',
#   'article_number': 224,
#   'number_ar': 'الرابعة والعشرون بعد المائتين',
#   'arabic_content': '90 \n)ملــــــغاة('},
#  {'index': 228,
#   'part_title_ar': 'هيئات تسوية الخلافات العمالية',
#   'part_number_ar': 'الرابع عشر',
#   'part_number': 4,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الخامسة والعشرون بعد المائتين',
#   'article_number': 225,
#   'number_ar': 'الخامسة والعشرون بعد المائتين',
#   'arabic_content': '91 \n\n)ملــــــغاة('},
#  {'index': 229,
#   'part_title_ar': 'هيئات تسوية الخلافات العمالية',
#   'part_number_ar': 'الرابع عشر',
#   'part_number': 4,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة السادسة والعشرون بعد المائتين',
#   'article_number': 226,
#   'number_ar': 'السادسة والعشرون بعد المائتين',
#   'arabic_content': '92 \n)ملــــــغاة('},
#  {'index': 230,
#   'part_title_ar': 'هيئات تسوية الخلافات العمالية',
#   'part_number_ar': 'الرابع عشر',
#   'part_number': 4,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة السابعة والعشرون بعد المائتين',
#   'article_number': 227,
#   'number_ar': 'السابعة والعشرون بعد المائتين',
#   'arabic_content': '93 \n)ملــــــغاة('},
#  {'index': 231,
#   'part_title_ar': 'هيئات تسوية الخلافات العمالية',
#   'part_number_ar': 'الرابع عشر',
#   'part_number': 4,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثامنة والعشرون بعد المائتين',
#   'article_number': 228,
#   'number_ar': 'الثامنة والعشرون بعد المائتين',
#   'arabic_content': '94 \n\n)ملــــــغاة( \n \n \n \n \n \n \n \n \n\n \n\n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n ألغيت بالمرسوم الملكي رقم )م/1( وتاريخ 22/1/1435هـ . \n\n \n59 \n\n \n \n \n \n \n\n15'},
#  {'index': 232,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة التاسعة والعشرون بعد المائتين',
#   'article_number': 229,
#   'number_ar': 'التاسعة والعشرون بعد المائتين',
#   'arabic_content': '95 \n\n1 – مــع عــدم الإخــلال بــأي عقوبــة أشــد يــنص عليهــا نظــام آخــر، يعاقــب كــل مــن يخــل بــأي حكــم مــن أحكــام هــذا النظــام أو لائحتــه أو \nالقرارات الصادرة تنفيذا له، بعقوبة أو أكثر من العقوبات الآتية : \n\nأ – غرامة مالية لا تتجاوز مائة ألف ريـال. \n\nب – إغلاق المنشأة لمدة لا تزيد على ثلاثين يوماً. \n\nج – إغلاق المنشأة نهائيًّا. \n\n2 – يجوز مضاعفة العقوبة الموقعة على المخالف في حال تكرار ارتكاب لمخالفة. \n\n3 – تتعدد الغرامات بتعدد الأشخاص الذين وقعت المخالفة في شأنهم.'},
#  {'index': 233,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة التاسعة والعشرون بعد المائتين مكرر',
#   'article_number': 229,
#   'number_ar': 'التاسعة والعشرون بعد المائتين مكرر',
#   'arabic_content': '96 \n\nيعاقــب بغرامــة لا تقــل عــن )200,000( مــائتي ألــف ريــال ولا تزيــد علــى )500,000( خمســمائة ألــف ريــال؛ كــل مــن يخــالف أحكــام الفقــرة \n)1( من المادة )الثلاثين( من هذا النظام، وذلك دون إخلال بما تقضي به المادة )التاسعة والعشرون بعد المائتين( منه.'},
#  {'index': 234,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثلاثون بعد المائتين',
#   'article_number': 230,
#   'number_ar': 'الثلاثون بعد المائتين',
#   'arabic_content': '97 \n\n1. للـــوزارة - بقـــرار مـــن الـــوزير أو مـــن ينيبـــه - إيقـــاع العقـــوبتين أو إحـــداهما المنصـــوص عليهمـــا فـــي الفقـــرتين الفـــرعيتين )أ( و)ب( \n\nمــن الفقــرة )1( مــن المــادة )التاســعة والعشــرين بعــد المــائتين( مــن هــذا النظــام، بمــا لا يتجــاوز نصــف الحــد الأعلــى المقــرر لأيً \nمنهما، ويجوز التظلم من القرار الصادر بالعقوبة أمام المحكمة الإدارية المختصة . \n\n2. يصــدر - بقــرار مــن الــوزير - جــدول تحــدد فيــه المخالفــات والعقوبــات المقابلــة لهــا التــي لا تتجــاوز نصــف الحــد الأعلــى للعقــوبتين \n\nالــواردتين فــي الفقــرتين الفــرعيتين )أ( و)ب( مــن الفقــرة )1( مــن المــادة )التاســعة والعشــرين بعــد المــائتين( مــن هــذا النظــام ، \nويراعى في ذلك التدرج في تحديد مقدارها وتناسبها مع جسامة المخالفة . \n\n3. يصــدر - بقــرار مــن الــوزير - جــدول تحــدد فيــه المخالفــات التــي تتجــاوز عقوباتهــا نصــف الحــد الأعلــى للعقــوبتين الــواردتين فــي \n\nالفقـــرتين الفـــرعيتين )أ( و)ب( مـــن الفقـــرة )1( مـــن المـــادة )التاســـعة والعشـــرين بعـــد المـــائتين( مـــن هـــذا النظـــام ، وتحـــدد فيـــه \nكذلك المخالفات التي تكون عقوبتها العقوبة الواردة في الفقرة الفرعية )ج( من الفقرة )1( من المادة المذكورة . \n\n4. إذا كانـــت المخالفـــة تســـتوجب عقوبـــة تزيـــد علـــى نصـــف الحـــد الأعلـــى المقـــرر لهـــا ، أو كانـــت مـــن المخالفـــات التـــي تســـتوجب \n\nعقوبـــة الإغـــلاق النهـــائي للمنشـــأة ، وفقـــاً للجـــدول المنصـــوص عليـــه فـــي الفقـــرة )3( مـــن هـــذه المـــادة ؛ فترفـــع الـــوزارة دعـــوى \nأمـــام المحكمـــة المختصـــة للنظـــر فيهـــا وإيقـــاع العقوبـــة المناســـبة المنصـــوص عليهـــا فـــي المـــادة )التاســـعة والعشـــرين بعـــد \nالمائتين( من هذا النظام. \n\n5. يجــوز الاتفــاق بــين الــوزارة والمخــالف علــى تســوية المخالفــة ، وذلــك بــدفع مبلــغ الغرامــة الــذي تقــدره الــوزارة ، علــى أن يصــدر \n\nبهذه التسوية قرار من الوزير أو من ينيبه.'},
#  {'index': 235,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الحادية والثلاثون بعد المائتين',
#   'article_number': 231,
#   'number_ar': 'الحادية والثلاثون بعد المائتين',
#   'arabic_content': '98 \nيلزم مرتكب المخالفة بإزالة المخالفة خلال مهلة تحددها اللائحة ، وفي حالة عدم إزالتها تعد مخالفة جديدة .'},
#  {'index': 236,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثانية والثلاثون بعد المائتين',
#   'article_number': 232,
#   'number_ar': 'الثانية والثلاثون بعد المائتين',
#   'arabic_content': '99 \n\nيــتم تحصــيل الغرامـــات المقــررة بموجــب هــذا النظــام ، وفقــاً للإجــراءات المتبعــة فــي تحصــيل الأمــوال العامــة ، وتــؤول المبــالغ إلــى \n\nصندوق تنمية الموارد البشرية .'},
#  {'index': 237,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثالثة والثلاثين بعد المائتين',
#   'article_number': 233,
#   'number_ar': 'الثالثة والثلاثين بعد المائتين',
#   'arabic_content': '100 \n\nللــوزير مــنح مكافــأة ماليــة لا تزيــد علــى )25%( مــن مبلــغ الغرامــة المحصــلة لمــن يســاعد - مــن مــوظفي التفتــيش أو مــن غيــرهم - \nفي الكشف عن أي من مخالفات أحكام هذا النظام ولائحته والقرارات الصادرة تنفيذاً له. \n\n \n \n \n \n\n \n\n95-  عدلت بناءً على المرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n96-أضيفت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هــ،  \n97-عدلت هذه المادة بناءً على المرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ ، وعدلت هذه المادة بناءً على المرسوم الملكي رقم )م/44( بتاريخ 8/2/1446هــ. \n98- عدلت بناءً على  المرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n\n 99- تم تعديل هذه المادة ونقلها لتكون )الثانية والثلاثين بعد المائتين( بموجب المرسوم الملكي رقم ) م/ 46( وتاريخ 5 / 6 / 1436 هـ . \n\n100-أضيفت هذه المادة بناء على  المرسوم الملكي رقم )م/ 4٦( وتاريخ 5 / ٦ / 143٦ هـ. \n\n \n61'},
#  {'index': 238,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الرابعة والثلاثين بعد المائتين',
#   'article_number': 234,
#   'number_ar': 'الرابعة والثلاثين بعد المائتين',
#   'arabic_content': '101 \nأ-لا تقبــل أمــام المحــاكم العماليــة أي دعــوى تتعلــق بالمطالبــة بحــق مــن الحقــوق المنصــوص عليهــا فــي هــذا النظــام أو الناشــئة عــن \nعقــد العمــل بعــد مضــي اثنــي عشــر شــهراً مــن تــاريخ انتهــاء علاقــة العمــل، مــا لــم يقــدم المــدعي عــذراً تقبلــه المحكمــة، أو يصــدر مــن \nالمدعى عليه إقرار بالحق. \n\nب-تنظر الدعاوى العمالية على وجه الاستعجال.'},
#  {'index': 239,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الخامسة والثلاثين بعد المائتين',
#   'article_number': 235,
#   'number_ar': 'الخامسة والثلاثين بعد المائتين',
#   'arabic_content': '102 \nلا يجـــوز لصـــاحب العمـــل أثنـــاء نظـــر الـــدعوى أمـــام المحـــاكم العماليـــة أن يغيـــر مـــن شـــروط التشـــغيل التـــي كانـــت ســـارية قبـــل بـــدء \nالإجراءات، تغييراً يترتب عليه الإضرار بموقف العامل في الدعوى.'},
#  {'index': 240,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة السادسة والثلاثين بعد المائتين',
#   'article_number': 236,
#   'number_ar': 'السادسة والثلاثين بعد المائتين',
#   'arabic_content': '103 \n\n)ملــــــغاة('},
#  {'index': 241,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة السابعة والثلاثين بعد المائتين',
#   'article_number': 237,
#   'number_ar': 'السابعة والثلاثين بعد المائتين',
#   'arabic_content': '104 \n\n)ملــــــغاة('},
#  {'index': 242,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثامنة والثلاثين بعد المائتين',
#   'article_number': 238,
#   'number_ar': 'الثامنة والثلاثين بعد المائتين',
#   'arabic_content': '105 \n\n)ملــــــغاة('},
#  {'index': 243,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة التاسعة والثلاثين بعد المائتين',
#   'article_number': 239,
#   'number_ar': 'التاسعة والثلاثين بعد المائتين',
#   'arabic_content': '106 \n\n)ملــــــغاة('},
#  {'index': 244,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الأربعون بعد المائتين',
#   'article_number': 240,
#   'number_ar': 'الأربعون بعد المائتين',
#   'arabic_content': '107 \n\n)ملــــــغاة('},
#  {'index': 245,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الحادية والأربعون بعد المائتين',
#   'article_number': 241,
#   'number_ar': 'الحادية والأربعون بعد المائتين',
#   'arabic_content': '108 \n\n)ملــــــغاة('},
#  {'index': 246,
#   'part_title_ar': 'العقوبات',
#   'part_number_ar': 'الخامس عشر',
#   'part_number': 5,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثانية والأربعون بعد المائتين',
#   'article_number': 242,
#   'number_ar': 'الثانية والأربعون بعد المائتين',
#   'arabic_content': '109 \n\n)ملــــــغاة( \n\n  \n\n \n\n101-أضيفت هذه المادة بموجب المرسوم الملكي رقم )م/14( وتاريخ 22/2/1440هـ. \n102- أضيفت هذه المادة بموجب المرسوم الملكي رقم )م/14( وتاريخ 22/2/1440هـ. \n103- عدل حكمها مع إعادة صياغة في المادتين )التاسعة والعشرين بعد المائتين( و)الثلاثين بعد المائتين( بالمرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n104- عدل حكمها مع إعادة صياغة في المادتين )التاسعة والعشرين بعد المائتين(و)الثلاثين بعد المائتين( بالمرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n105- عدل حكمها مع إعادة صياغة في المادتين )التاسعة والعشرين بعد المائتين(و)الثلاثين بعد المائتين( بالمرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n106- عدل حكمها مع إعادة صياغة في المادتين )التاسعة والعشرين بعد المائتين(و)الثلاثين بعد المائتين( بالمرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n107- عدلت ونقلت لتكون المادة )الحادية والثلاثين بعد المائتين( بالمرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n108- عدل حكمها مع إعادة صياغة في المادتين )التاسعة والعشرين بعد المائتين(و)الثلاثين بعد المائتين( بالمرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n109-  عدلت ونقلت لتكون المادة )الثانية والثلاثين بعد المائتين( بالمرسوم الملكي رقم )م/46( وتاريخ 5/6/1436هـ . \n\n \n62 \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n16'},
#  {'index': 247,
#   'part_title_ar': 'أحكام ختامية',
#   'part_number_ar': 'السادس عشر',
#   'part_number': 6,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الثالثة والأربعون بعد المائتين',
#   'article_number': 243,
#   'number_ar': 'الثالثة والأربعون بعد المائتين',
#   'arabic_content': 'يصــدر الــوزير القــرارات واللــوائح اللازمــة لتنفيــذ أحكــام هــذا النظــام خــلال مائــة وثمــانين يومــاً مــن تــاريخ العمــل بهــذا النظــام ، وتنشــر \nاللوائح التنفيذية في الجريدة الرسمية .'},
#  {'index': 248,
#   'part_title_ar': 'أحكام ختامية',
#   'part_number_ar': 'السادس عشر',
#   'part_number': 6,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الرابعة والأربعون بعد المائتين',
#   'article_number': 244,
#   'number_ar': 'الرابعة والأربعون بعد المائتين',
#   'arabic_content': 'يحـــل هـــذا النظـــام محـــل نظـــام العمـــل والعمـــال ، الصـــادر بالمرســـوم ذي الـــرقم ) م/21( والتـــاريخ 6/9/1389هــــ ، ويلغـــي كـــل مـــا \nيتعارض معه من أحكام ويستمر العمل باللوائح والقرارات الصادرة قبل نفاذ هذا النظام إلى حين تعديلها .'},
#  {'index': 249,
#   'part_title_ar': 'أحكام ختامية',
#   'part_number_ar': 'السادس عشر',
#   'part_number': 6,
#   'chapter_title_ar': 'بدون فصل',
#   'chapter_number_ar': None,
#   'chapter_number': None,
#   'arabic_name': 'المادة الخامسة والأربعون بعد المائتين',
#   'article_number': 245,
#   'number_ar': 'الخامسة والأربعون بعد المائتين',
#   'arabic_content': 'ينشر هذا النظام في الجريدة الرسمية ويعمل به بعد مائة وثمانين يوماً من تاريخ نشره. \n\n \n\n \n\nوﷲ الموفق ,,, \n\n \n\n \n\n \n\n \n\n \n \n \n \n \n \n\n \n64 \n\n \n \n\n \n \n\n0\n \n\n \n\n www.hrsd.gov.sa'}]
